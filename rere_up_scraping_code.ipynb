# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import os
import openpyxl
from openpyxl import load_workbook
url = "https://www.up-rera.in/projects"
from selenium import webdriver
def driver_call(url):
        global driver
        #System.setProperty("webdriver.chrome.driver","/usr/bin/chromedriver");
        driver = webdriver.Chrome(executable_path="/home/anm/Downloads/chromedriver_linux64 (2)/chromedriver")
        #driver= webdriver.Chrome(executable_path="/home/anm/Downloads/chromedriver_linux64/chromedriver")
        driver.get(url)
        time.sleep(8)
def get_all_tables(soup):
    """Extracts and returns all tables in a soup object"""
    return soup.find_all("table")
def get_all_tables(soup):
    """Extracts and returns all tables in a soup object"""
    return soup.find_all("table")
def get_table_headers(table):
    """Given a table soup, returns all the headers"""
    headers = []
    for th in table.find("tr").find_all("th"):
        headers.append(th.text.strip())
    return headers
def get_table_rows(table):
    """Given a table, returns all its rows"""
    rows = []
    for tr in table.find_all("tr")[1:]:
        cells = []
        # grab all td tags in this table row
        tds = tr.find_all("td")
        if len(tds) == 0:
            # if no td tags, search for th tags
            # can be found especially in wikipedia tables below the table
            ths = tr.find_all("th")
            for th in ths:
                cells.append(th.text.strip())
        else:
            # use regular td tags
            for td in tds:
                cells.append(td.text.strip())
        rows.append(cells)
    return rows
def save_as_csv(table_name, headers, rows, writer):
    #pd.DataFrame(rows, columns=headers).to_csv(f"{table_name}.csv")
    # Create a Pandas Excel writer using XlsxWriter as the engine.
    #writer = pd.ExcelWriter('pandas_multiple.xlsx', engine='xlsxwriter')
   



    # Write each dataframe to a different worksheet.
    pd.DataFrame(rows, columns=headers).to_excel(writer, sheet_name="{}".format(table_name))
    writer.save()
    writer.close()
    
def save_as_csv_dummy(writer, table_name):
    
    # Write each dataframe to a different worksheet.
    pd.DataFrame().to_excel(writer, sheet_name="{}".format(table_name))
    writer.save()
    writer.close()

# %%
 l=["%.2d" % i for i in range(1,16)]

# %%
l
# Out:
# ['01',
#  '02',
#  '03',
#  '04',
#  '05',
#  '06',
#  '07',
#  '08',
#  '09',
#  '10',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15']

# %%
driver_call(url)
time.sleep(10)
elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_btnSearch"]')
elementID.click()
l=["%.2d" % i for i in range(2,2833)]
for m in l:
    elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl'+str(m)+'_LnkView"]')
    elementID.click()
    time.sleep(5)
    driver.execute_script("window.history.go(-1)")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1ecdf7c0b933> in <module>
#       6 for m in l:
#       7     elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl'+str(m)+'_LnkView"]')
# ----> 8     elementID.click()
#       9     time.sleep(5)
#      10     driver.execute_script("window.history.go(-1)")
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/.local/lib/python3.6/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      78         else:
#      79             return self.request_encode_body(
# ---> 80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#      82
#
# ~/.local/lib/python3.6/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# ~/.local/lib/python3.6/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/.local/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     309         # read until we get a non-100 response
#     310         while True:
# --> 311             version, status, reason = self._read_status()
#     312             if status != CONTINUE:
#     313                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     270
#     271     def _read_status(self):
# --> 272         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     273         if len(line) > _MAXLINE:
#     274             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
driver_call(url)
time.sleep(10)
elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_btnSearch"]')
elementID.click()
l=["%.2d" % i for i in range(2,2833)]
for m in l:
    elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl'+str(m)+'_LnkView"]')
    elementID.click()
    time.sleep(5)
    elementID=driver.find_element_by_xpath('//*[@id="contentSection"]/div/div/div/div/div[2]/div[27]/div[3]/a/b')
    elementID.click()
    time.sleep(10)
    driver.switch_to.window(driver.window_handles[1])
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
    print(driver.window_handles)
    
    driver.execute_script("window.history.go(-1)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-69e9799f5d45> in <module>
# ----> 1 driver_call(url)
#       2 time.sleep(10)
#       3 elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_btnSearch"]')
#       4 elementID.click()
#       5 l=["%.2d" % i for i in range(2,2833)]
#
# NameError: name 'driver_call' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-119-3b145d6c077c> in <module>
#       7 for a in table.find_all('a', href=True):
#       8     ntab_url = "https://www.up-rera.in/projects/"+a['href']
# ----> 9     driver.execute_script('''window.open("","_blank");''')
#      10     driver.switch_to.window(driver.window_handles[1])
#      11     driver.get(ntab_url)
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=86.0.4240.111)

# %%
//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl02_LnkView"]//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl02_LnkView"]

# %%
driver_call(url)
time.sleep(5)
Project_approved=[]         
Project_details = []
k=0
Project_details_list = [] 
#captcha=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_txtcap"]')
elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_btnSearch"]')
elementID.click()
l=["%.2d" % i for i in range(2,2833)]
for m in l:
    elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl'+str(m)+'_LnkView"]')
    elementID.click()
    time.sleep(10)

    elementID=driver.find_element_by_xpath('//*[@id="contentSection"]/div/div/div/div/div[2]/div[27]/div[3]/a/b')
    elementID.click()
    time.sleep(10)
    driver.switch_to.window(driver.window_handles[-1])
    soup = BeautifulSoup(driver.page_source, 'lxml')
    Project_name=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblProjectName"]').text
    Project_id=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblProjectNameWithID"]').text
    Registration_date=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblregisdate"]').text
    Promoter_name=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblPromoterNameHeading"]').text
    Promoter_id=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblPromoterNameWithID"]').text
    Project_type=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblProjectType"]').text
    Project_category=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblProjectCategory"]').text
    total_area=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblTotalArea"]').get_attribute("value")
    Registration_fee=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_PanelBasicDetails"]/div/div/fieldset/table/tbody/tr[5]/td[4]').text
    Project_duratin_in_month=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblProjectDuration"]').text
    Orginal_start_date=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblOriginalStartDate"]').get_attribute("value")
    Proposed_start_date=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblStartDate"]').get_attribute("value")
    Proposed_completion_date=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblEndDate"]').get_attribute("value")
    Project_cost=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblProjectCost"]').get_attribute("value")
    Sanctioning_Competent_Authority=soup.find('select', id = 'ctl00_ContentPlaceHolder1_ddlAuthority').find('option', selected = True).text
    Tehsil=soup.find('select', id = 'ctl00_ContentPlaceHolder1_ddlTehsil').find('option', selected = True).text
    District=soup.find('select', id = 'ctl00_ContentPlaceHolder1_ddlDistrict').find('option', selected = True).text
    State=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblState"]').text
    Latitute=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblLat1"]').get_attribute("value")
    Longtitute=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblLong1"]').get_attribute("value")
    id_list=["ShowTableApartment","ctl00_ContentPlaceHolder1_grddevlopmentworks","dbkhasradetails",
             "ctl00_ContentPlaceHolder1_grvagents"]              
    driver.switch_to.window(driver.window_handles[-1])
    soup = BeautifulSoup(driver.page_source, 'lxml')
    #TARGET_DIR = f'/home/anm/rera_up/sheet'
    #tables = soup.find('table',id =["ShowTableApartment","ctl00_ContentPlaceHolder1_grddevlopmentworks"])
    tables = soup.find('table',id ="ctl00_ContentPlaceHolder1_grddevlopmentworks")
    #collect_table(soup, id_list)
    tables = []    
    for i in id_list:

        temp = soup.find('table',id = i)
        temp

        tables.append(temp)    
    for i in range(0, len(tables)): 
        headers = []
    for th in tables[i].find("tr").find_all("th"):
        headers.append(th.text.strip())

    TARGET_DIR = f'/home/anm/rera_up/sheet/'

    # iterate over all tables
    filepath = "{}project_{}.xlsx".format(TARGET_DIR,k+1)
    wb = openpyxl.Workbook()
    wb.save(filepath)
    print(filepath)
    counter=0
    print("Created excel file project_{}.xlsx".format(k+1))
    for num_tables, table in enumerate(tables, start=1):
        # get the table headers
        headers = get_table_headers(table)
        # get all the rows of the table
        rows = get_table_rows(table)
        # Create a Pandas Excel writer using XlsxWriter as the engine.
        #writer = pd.ExcelWriter('pandas_multiple.xlsx', engine='xlsxwriter')
        path = "{}project_{}.xlsx".format(TARGET_DIR,k+1)
        book = load_workbook(path)
        writer = pd.ExcelWriter(path, engine = 'openpyxl')
        writer.book = book
        sheet_name=["Apartments details","Development works","Plot details","Agent name"]
        #for k in range(sheet_name):
        table_name = sheet_name[counter]
        counter=counter+1
        print(f"[+] Saving {table_name}")
        save_as_csv(table_name, headers, rows, writer)





    Project_details = [Project_name,Project_id,Registration_date,Promoter_name,Promoter_id,Project_type,
                     Project_category,total_area,Registration_fee,Project_duratin_in_month,Orginal_start_date,
                       Proposed_start_date,Proposed_completion_date,Project_cost,Sanctioning_Competent_Authority,
                       Tehsil,District,State,Latitute,Longtitute]
    Project_details_list.append(Project_details)
    time.sleep(5)
    #driver.close()
    driver.switch_to.window(driver.window_handles[-1])
    driver.execute_script("window.history.go(-1)")
#driver.switch_to.window(driver.window_handles[-1])
#driver.execute_script("window.history.go(-1)")
Project_details_list_df = pd.DataFrame(Project_details_list,columns =['Project_name','Project_id','Registration_date','Promoter_name','Promoter_id','Project_type',
                 'Project_category','total_area','Registration_fee','Project_duratin_in_month','Orginal_start_date',
                   'Proposed_start_date','Proposed_completion_date','Project_cost','Sanctioning_Competent_Authority',
                   'Tehsil','District','State','Latitute','Longtitute'])


Project_details_list_df.to_csv("/home/anm/rera_up/project_up.csv", index = False)
print("Task Completed")
# Out:
# /home/anm/rera_up/sheet/project_1.xlsx
# Created excel file project_1.xlsx
# [+] Saving Apartments details
# [+] Saving Development works
# [+] Saving Plot details
# [+] Saving Agent name
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-8-0939872ea124> in <module>
#      10 l=["%.2d" % i for i in range(2,2833)]
#      11 for m in l:
# ---> 12     elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl'+str(m)+'_LnkView"]')
#      13     elementID.click()
#      14     time.sleep(10)
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl03_LnkView"]"}
#   (Session info: chrome=86.0.4240.111)

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-130-4a9c0cd610a1> in <module>
# ----> 1 soup = BeautifulSoup(driver.page_source, 'lxml')
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=86.0.4240.111)

# %%
District=soup.find('select', id = 'ctl00_ContentPlaceHolder1_ddlDistrict').find('option', selected = True).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-131-0313ed13ea3c> in <module>
# ----> 1 District=soup.find('select', id = 'ctl00_ContentPlaceHolder1_ddlDistrict').find('option', selected = True).text
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
Tehsil=soup.find('select', id = 'ctl00_ContentPlaceHolder1_ddlTehsil').find('option', selected = True).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-5618f1570a94> in <module>
# ----> 1 Tehsil=soup.find('select', id = 'ctl00_ContentPlaceHolder1_ddlTehsil').find('option', selected = True).text
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
Sanctioning_Competent_Authority=soup.find('select', id = 'ctl00_ContentPlaceHolder1_ddlAuthority').find('option', selected = True).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-810623e27f3d> in <module>
# ----> 1 Sanctioning_Competent_Authority=soup.find('select', id = 'ctl00_ContentPlaceHolder1_ddlAuthority').find('option', selected = True).text
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
Project_details_list_df = pd.DataFrame(Project_details_list,columns =['Project_name','Project_id','Registration_date','Promoter_name','Promoter_id','Project_type',
                 'Project_category','total_area','Registration_fee','Project_duratin_in_month','Orginal_start_date',
                   'Proposed_start_date','Proposed_completion_date','Project_cost','Sanctioning_Competent_Authority',
                   'Tehsil','District','State','Latitute','Longtitute'])

# %%
Project_details_list_df
# Out:
#   Project_name                  Project_id              Registration_date  \
# 0   ATS ALLURE  Project Id: (UPRERAPRJ918)  Registration Date: 31-07-2017
#
#                                Promoter_name                   Promoter_id  \
# 0  Promoter Name: ATS Realty Private Limited  Promoter Id: (UPRERAPRM2628)
#
#   Project_type Project_category total_area Registration_fee  \
# 0      Ongoing      Residential      34323          : 43520
#
#   Project_duratin_in_month Orginal_start_date Proposed_start_date  \
# 0                       63         04-07-2014          04-07-2014
#
#   Proposed_completion_date Project_cost Sanctioning_Competent_Authority  \
# 0               04-09-2019       177000     Yamuna Expressway Authority
#
#                 Tehsil             District          State  Latitute  \
# 0  Gautam Buddha Nagar  Gautam Buddha Nagar  Uttar Pradesh  28.28759
#
#   Longtitute
# 0  77.560314

# %%
district_meta = soup.find('select', id = 'ctl00_ContentPlaceHolder1_ddlDistrict').find('option', selected = True).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-d187e8b6a7cb> in <module>
# ----> 1 district_meta = soup.find('select', id = 'ctl00_ContentPlaceHolder1_ddlDistrict').find('option', selected = True).text
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
district_meta
# Out:
# 'Gautam Buddha Nagar'

# %%
Project_cost=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblProjectCost"]').get_attribute("value")

# %%
Orginal_start_date=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblOriginalStartDate"]').get_attribute("value")

# %%
driver_call(url)
file=1
time.sleep(10)
Project_approved=[]         
Project_details = []
Project_details_list = [] 
#captcha=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_txtcap"]')
elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_btnSearch"]')
elementID.click()
elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl02_LnkView"]')
elementID.click()
time.sleep(10)

elementID=driver.find_element_by_xpath('//*[@id="contentSection"]/div/div/div/div/div[2]/div[27]/div[3]/a/b')
elementID.click()
time.sleep(10)
driver.switch_to.window(driver.window_handles[-1])
soup = BeautifulSoup(driver.page_source, 'lxml')
print(soup)
#TARGET_DIR = f'/home/anm/rera_up/sheet'
#tables = soup.find('table',id =["ShowTableApartment","ctl00_ContentPlaceHolder1_grddevlopmentworks"])
tables = soup.find('table',id ="ctl00_ContentPlaceHolder1_grddevlopmentworks")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-4-f24116172a48> in <module>
#      15 elementID.click()
#      16 time.sleep(10)
# ---> 17 driver.switch_to.window(driver.window_handles[-1])
#      18 soup = BeautifulSoup(driver.page_source, 'lxml')
#      19 print(soup)
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in window_handles(self)
#     722         """
#     723         if self.w3c:
# --> 724             return self.execute(Command.W3C_GET_WINDOW_HANDLES)['value']
#     725         else:
#     726             return self.execute(Command.GET_WINDOW_HANDLES)['value']
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=86.0.4240.111)

# %% [markdown]
# table = tables
# tab_data = [[cell.text for cell in row.find_all(["th","td"])]
#                         for row in table.find_all("tr")]
# df = pd.DataFrame(tab_data)

# %% [markdown]
# df

# %% [markdown]
# df.to_excel("/home/anm/up_k.xlsx")

# %% [markdown]
# len(id_list)

# %% [markdown]
# table_topic_list

# %% [markdown]
# id_list

# %% [markdown]
# State

# %% [markdown]
# headers = get_table_headers(in_tables[num_table])

# %% [markdown]
# rows = get_table_rows(table)
# path = "{}Project_{}.xlsx".format(TARGET_DIR,file)
# book = load_workbook(path)
# writer = pd.ExcelWriter(path, engine = 'openpyxl')
# writer.book = book
#
# # save table as sheet
# table_name = table_topic_list[counter]
# #counter = counter + 1
# print(f"[+] Saving {table_name}")
# print(headers)
# print(rows)
# save_as_csv(table_name, headers, rows, writer)

# %% [markdown]
# rows = get_table_rows(table)

# %% [markdown]
# rows

# %% [markdown]
# table_header = soup.find("table", id = id_list[il]).select("th")
# if(len(table_header) > 0):
#         for j in range(len(table_header)):
#             table_topic=table_header[j].text
#             print(table_topic)
#             table_topic_list.append(table_topic)

# %% [markdown]
# table_topic

# %% [markdown]
# table_header

# %% [markdown]
# table_topic_list

# %% [markdown]
# table_list = soup.find("table", id = id_list[il]).select("td")

# %% [markdown]
# print(table_list)

# %% [markdown]
# print(f"[+] Found a total of {len(table_list)} tables.")
#
# if(len(table_list) > 0):
#
#     counter = 0
#
#     nested_table = []
#     in_tables = []
#
# for t in table_list:
#     nest = len(t.find_parents("table"))
#     if nest == 1:
#         in_tables.append(t)
#     nested_table.append(nest)

# %% [markdown]
# for num_table in range(len(table_list)):
#         #try:
#         # get the table headers
#         headers = get_table_headers(table_list[num_table])
#         # get all the rows of the table
#         rows = get_table_rows(table_list[num_table])
#         path = "{}Project_{}.xlsx".format(TARGET_DIR,file)
#         book = load_workbook(path)
#         writer = pd.ExcelWriter(path, engine = 'openpyxl')
#         writer.book = book
#
#         # save table as sheet
#         table_name = table_topic_list[counter]
#         counter = counter + 1
#         print(f"[+] Saving {table_name}")
#         print(headers)
#         print(rows)
#         save_as_csv(table_name, headers, rows, writer)

# %% [markdown]
# table_list = soup.find("table").select("td")

# %% [markdown]
# table_list

# %% [markdown]
# i=1
# id_list=["ShowTableApartment","ctl00_ContentPlaceHolder1_grddevlopmentworks","dbkhasradetails",
#          "ctl00_ContentPlaceHolder1_grvagents"]
# for idr in id_list:
#     table = soup.find('table',id =idr)
#
#
#
#     TARGET_DIR = f'/home/anm/Downloads/'
#
#     # iterate over all tables
#     filepath = "{}up_{}.xlsx".format(TARGET_DIR,i+1)
#     wb = openpyxl.Workbook()
#     wb.save(filepath)
#     print(filepath)
#
#     print("Created excel file up_{}.xlsx".format(i+1))
#
#
#     for num_tables, table in enumerate(tables, start=1):
#         # get the table headers
#         headers = get_table_headers(table)
#         # get all the rows of the table
#         rows = get_table_rows(table)
#         # Create a Pandas Excel writer using XlsxWriter as the engine.
#         #writer = pd.ExcelWriter('pandas_multiple.xlsx', engine='xlsxwriter')
#
#
#
#         path = "{}up_{}.xlsx".format(TARGET_DIR,i+1)
#         book = load_workbook(path)
#         writer = pd.ExcelWriter(path, engine = 'openpyxl')
#         writer.book = book
#
#         # save table as sheet
#         table_name = f"table-{num_tables}"
#         print(f"[+] Saving {table_name}")
#         save_as_csv(table_name, headers, rows, writer)
#         i=i+1

# %% [markdown]
# table_list

# %% [markdown]
# for num_tables, table in enumerate(table_list, start=1):
#     # get the table headers
#     headers = get_table_headers(table)
#     # get all the rows of the table
#     rows = get_table_rows(table)
#     # Create a Pandas Excel writer using XlsxWriter as the engine.
#     #writer = pd.ExcelWriter('pandas_multiple.xlsx', engine='xlsxwriter')
#     path = "{}up_{}.xlsx".format(TARGET_DIR,i+1)
#     book = load_workbook(path)
#     writer = pd.ExcelWriter(path, engine = 'openpyxl')
#     writer.book = book
#     #table_name_list=["Apartment table","Development","Khasara details","Agent"]
#     # save table as sheet
#     table_name = f"table-{num_tables}"
#     print(f"[+] Saving {table_name}")
#     save_as_csv(table_name, headers, rows, writer)

# %% [markdown]
# for th in table.find("tr").find_all("th"):
#     headers.append(th.text.strip())
# headers

# %% [markdown]
# table_list = []
#
# for idr in id_list:
#     table = soup.find('table',id =idr)
#     table_list.append(table)
#
# table_list

# %% [markdown]
# i=1
# id_list=["ShowTableApartment","ctl00_ContentPlaceHolder1_grddevlopmentworks","dbkhasradetails",
#          "ctl00_ContentPlaceHolder1_grvagents"]
# for idr in id_list:
#     tables = soup.find('table',id =idr)
#
#
#
#     TARGET_DIR = f'/home/anm/Downloads/'
#
#     # iterate over all tables
#     filepath = "{}up_{}.xlsx".format(TARGET_DIR,i+1)
#     wb = openpyxl.Workbook()
#     wb.save(filepath)
#     print(filepath)
#
#     print("Created excel file up_{}.xlsx".format(i+1))
#
#
#     for num_tables, table in enumerate(tables, start=1):
#         # get the table headers
#         headers = get_table_headers(table)
#         # get all the rows of the table
#         rows = get_table_rows(table)
#         # Create a Pandas Excel writer using XlsxWriter as the engine.
#         #writer = pd.ExcelWriter('pandas_multiple.xlsx', engine='xlsxwriter')
#
#
#
#         path = "{}up_{}.xlsx".format(TARGET_DIR,i+1)
#         book = load_workbook(path)
#         writer = pd.ExcelWriter(path, engine = 'openpyxl')
#         writer.book = book
#
#         # save table as sheet
#         table_name = f"table-{num_tables}"
#         print(f"[+] Saving {table_name}")
#         save_as_csv(table_name, headers, rows, writer)
#         i=i+1

# %% [markdown]
# tables

# %%
tables
# Out:
# [<table border="1" class="table table-responsive" id="ShowTableApartment" style=" display:none;width: 100%!important">
#  </table>,
#  None,
#  <table border="1" class="table" id="dbkhasradetails"><tbody><tr>
#  <th>Type</th>
#  <th>Khasra/Plot No</th>
#  <th>Area(In Sq. Mt.)</th>
#  </tr></tbody></table>,
#  None]

# %%
id_list=["ShowTableApartment","ctl00_ContentPlaceHolder1_grddevlopmentworks","dbkhasradetails",
         "ctl00_ContentPlaceHolder1_grvagents"]
tables = []

              
for i in id_list:
    temp = soup.find('table',id = i)
    temp
    tables.append(temp)
    

for i in range(2, 3):

    headers = []
    
    for th in tables[i].find("tr").find_all("th"):
        headers.append(th.text.strip())
        
    print(headers)
# Out:
# <tr>
# <th>Type</th>
# <th>Khasra/Plot No</th>
# <th>Area(In Sq. Mt.)</th>
# </tr>
# []

# %%
headers
# Out:
# ['SNo.', 'Agent Name']

# %%
soup
# Out:
# <html><head id="ctl00_Head1"><link href="img/logo_hi.jpg" rel="shortcut icon" type="image/x-icon"/>
# <script src="js/jquery-2.2.4.min.js"></script>
# <link href="tcal.css" rel="stylesheet" type="text/css"/>
# <script src="tcal.js" type="text/javascript"></script>
# <style type="text/css">
#         .auto-style1 {
#             width: 219px;
#         }
#
#         .auto-style6 {
#             width: 400px;
#             height: 30px;
#             max-width: 100%;
#             margin-bottom: 5px;
#             font-weight: 700;
#             color: grey;
#         }
#
#         .auto-style7 {
#             width: 400px;
#             color: darkslategrey;
#         }
#
#         .auto-style20 {
#             width: 400px;
#             height: 30px;
#             max-width: 100%;
#             margin-bottom: 5px;
#             font-weight: 700;
#             color: darkslategrey;
#         }
#
#
#
#
#
#
#         /*Calendar Control CSS*/
#         .cal_Theme1 .ajax__calendar_container {
#             background-color: #808080;
#             border: solid 1px #77D5F7;
#         }
#
#         .cal_Theme1 .ajax__calendar_header {
#             background-color: #808080;
#             margin-bottom: 4px;
#         }
#
#         .cal_Theme1 .ajax__calendar_title,
#         .cal_Theme1 .ajax__calendar_next,
#         .cal_Theme1 .ajax__calendar_prev {
#             color: #004080;
#             padding-top: 3px;
#         }
#
#         .cal_Theme1 .ajax__calendar_body {
#             background-color: #ffffff;
#             border: solid 1px orange;
#         }
#
#         .cal_Theme1 .ajax__calendar_dayname {
#             text-align: center;
#             font-weight: bold;
#             margin-bottom: 4px;
#             margin-top: 2px;
#             color: #004080;
#         }
#
#         .cal_Theme1 .ajax__calendar_day {
#             color: #004080;
#             text-align: center;
#         }
#
#         .cal_Theme1 .ajax__calendar_hover .ajax__calendar_day,
#         .cal_Theme1 .ajax__calendar_hover .ajax__calendar_month,
#         .cal_Theme1 .ajax__calendar_hover .ajax__calendar_year,
#         .cal_Theme1 .ajax__calendar_active {
#             color: #004080;
#             font-weight: bold;
#             background-color: #DEF1F4;
#         }
#
#
#         .cal_Theme1 .ajax__calendar_today {
#             font-weight: bold;
#         }
#
#         .cal_Theme1 .ajax__calendar_other,
#         .cal_Theme1 .ajax__calendar_hover .ajax__calendar_today,
#         .cal_Theme1 .ajax__calendar_hover .ajax__calendar_title {
#             color: #bbbbbb;
#         }
#     </style>
# <style type="text/css">
#         body {
#             margin: 0;
#             padding: 0;
#             font-family: Arial;
#         }
#
#         .modal1 {
#             position: fixed;
#             z-index: 999;
#             height: 100%;
#             width: 100%;
#             top: 0;
#             background-color: Black;
#             filter: alpha(opacity=20);
#             opacity: 0.6;
#             -moz-opacity: 0.8;
#         }
#
#         .center {
#             z-index: 1000;
#             margin: 300px auto;
#             padding: 10px;
#             width: 130px;
#             /*background-color: White;*/
#             border-radius: 80%;
#             filter: alpha(opacity=50);
#             opacity: 1;
#             -moz-opacity: 1;
#         }
#
#             .center img {
#                 height: 200%;
#                 width: 200%;
#             }
#     </style>
# <script type="text/javascript">
#         document.addEventListener('contextmenu', function (e) {
#             e.preventDefault();
#         });
#         $(document).keydown(function (e) {
#             if (e.which === 123) {
#                 return false;
#             }
#         });
#
#
#         $(document).ready(function () {
#             $("#ctl00_ContentPlaceHolder1_ddlDistrict").removeClass().addClass("form-control");
#              $("#ctl00_ContentPlaceHolder1_ddlTehsil").removeClass().addClass("form-control");
#              $("#ctl00_ContentPlaceHolder1_lblProjectName").removeClass().addClass("form-control");
#          });
#          function GetFileName(fileUp) {
#
#              var filename = $(fileUp).val().split('\\').pop();
#              //alert(filename);
#              var extension = filename.substring(filename.lastIndexOf('.') + 1);
#              //alert(extension);
#              if (extension !== "pdf" && extension !== "PDF") {
#                  $(fileUp).val(null);
#                  alert("Only PDF files allowed  ");
#              }
#              if (fileUp.files[0].size > 2097152) {
#                  $(fileUp).val(null);
#                  alert("Files maximum size of 2 MB allowed");
#              } else {
#
#              }
#          }
#
#
#
#          function checkEdit() {
#              var projectid = '918';
#
#              $.ajax({
#                  type: "POST",
#                  url: "WebService1.asmx/bindVisibilityLink",
#                  data: "{projectid: '" + projectid + "'}",
#                  contentType: "application/json; charset=utf-8",
#                  dataType: "json",
#                  success: function (r) {
#
#                      var data = JSON.parse(r.d);
#
#                      for (var key in data) {
#                          if (data.hasOwnProperty(key)) {
#                              // here you have access to
#                              var ResVal = data[key].FieldUpdated;
#
#                              if (ResVal == "Sanctioning Competent Authority") {
#                                  $('#ctl00_ContentPlaceHolder1_lnkSaveCompetentAuthority').hide();
#                                  $('#ctl00_ContentPlaceHolder1_lnkEditCompetentAuthority').hide();
#
#
#                              }
#                              if (ResVal == "Tehsil") {
#                                  $('#ctl00_ContentPlaceHolder1_LinkEditTehsil').hide();
#                                  $('#ctl00_ContentPlaceHolder1_LinkSaveTehsil').hide();
#
#                              }
#
#                              if (ResVal == "Proposed End Date") {
#
#                                  $('#lnkEditrevisedEndDate_Admin').hide();
#
#                              }
#
#                              if (ResVal == "Geographic Location") {
#                                  $('#ctl00_ContentPlaceHolder1_LinkEdit_GeographicLocation').hide();
#                                  $('#ctl00_ContentPlaceHolder1_LinkSave_GeoLocation').hide();
#
#                              }
#                              if (ResVal == "Agent") {
#                                  $('#ctl00_ContentPlaceHolder1_linkAddAgent').hide();
#                              }
#
#
#                          }
#                      }
#
#
#
#
#                  },
#                  error: function (r) {
#                      alert(r.responseText);
#                  },
#                  failure: function (r) {
#                      alert(r.responseText);
#                  }
#              });
#
#
#
#
#          }
#
#
#
#          function SenctionPlan() {
#
#              // alert("ok");
#              var projectid = '918';
#
#              $.ajax({
#                  type: "POST",
#                  url: "WebService1.asmx/getplandetailsvalue",
#                  data: "{projectid: '" + projectid + "'}",
#                  contentType: "application/json; charset=utf-8",
#                  dataType: "json",
#                  success: function (r) {
#
#                      var data = r.d;
#                      //alert(data);
#                      $('#ctl00_ContentPlaceHolder1_ddlgettype').val(data);
#
#                      if (data == "Plot") {
#
#                          $('#tblapartment').show();
#                          $('#ctl00_ContentPlaceHolder1_ddlgettype').html("");
#                          $('#ctl00_ContentPlaceHolder1_ddlgettype').append($('<option></option>')
#                       .attr('value', "Plot")
#                       .text("Plot"));
#
#                          getpropertytype();
#                          $('#ctl00_ContentPlaceHolder1_permitsection').show();
#
#                         $('#ddlgettyperow').show();
#                     }
#
#                      if (data == "villa") {
#
#                          $('#tblapartment').show();
#                          $('#ctl00_ContentPlaceHolder1_ddlgettype').html("");
#                          $('#ctl00_ContentPlaceHolder1_ddlgettype').append($('<option></option>')
#                       .attr('value', "villa")
#                       .text("Villa"));
#
#                          getpropertytype();
#                          $('#ctl00_ContentPlaceHolder1_permitsection').show();
#
#                          $('#ddlgettyperow').show();
#                      }
#
#
#                      if (data == "AFS") {
#
#                          $('#tblapartment').show();
#
#                          $('#ctl00_ContentPlaceHolder1_ddlgettype').html("");
#                          $('#ctl00_ContentPlaceHolder1_ddlgettype').append($('<option></option>')
#                       .attr('value', "AFS")
#                       .text("Apartment/Flat/Shop"));
#
#                          getpropertytype();
#                          $('#ctl00_ContentPlaceHolder1_permitsection').show();
#                         $('#ddlgettyperow').show();
#
#
#
#
#
#                     }
#
#                      if (data == "Mix") {
#
#                          $('#tblapartment').show();
#
#                          $('#ctl00_ContentPlaceHolder1_ddlgettype').html("");
#                          $('#ctl00_ContentPlaceHolder1_ddlgettype').append($('<option></option>')
#                            .attr('value', "Mix")
#                            .text("Mix"));
#
#                          getpropertytype();
#                          $('#ctl00_ContentPlaceHolder1_permitsection').show();
#                               $('#ddlgettyperow').show();
#
#
#                               $('#ShowTablePlots').show();
#                               $('#td_villa').show();
#
#
#                               $('#ctl00_ContentPlaceHolder1_permitsection').show();
#
#                          //$('#ddlgettyperow').hide();
#                      }
#
#                      else {
#                          $('#tblapartment').hide();
#
#                          $('#ddlgettyperow').hide();
#
#
#                      }
#                  },
#                  error: function (r) {
#                      alert(r.responseText);
#                  },
#                  failure: function (r) {
#                      alert(r.responseText);
#                  }
#              });
#          }
#
#
#
#
#
#          $(document).ready(function () {
#
#              $('#ctl00_ContentPlaceHolder1_txtPermitValidUpto').on('change', function () {
#
#                  $('#ctl00_ContentPlaceHolder1_txtrevised_end_date').val('');
#             })
#
#              var projectid = '918';
#              if (projectid != '') {
#                  $('#lnkEditrevisedEndDate_Admin').hide();
#              }
#              else {
#                  $('#lnkEditrevisedEndDate_Admin').show();
#              }
#
#              $("#lblname").text("");
#              $("#lbldate").text("");
#              $("#txtdate_docs").hide();
#              $("#txtno").hide();
#
#              checkEdit();
#              SenctionPlan();
#
#
#              $(document.getElementById('ctl00_ContentPlaceHolder1_btnSanctionedPlan')).click(function () {
#
#                  var status = validateplan();
#
#                  if (status == true) {
#
#                      $("#imagen").show();
#                      var ajax = $.ajax({
#                          type: "GET",
#                          //  url: 'datos.txt',
#                          success: function (data) {
#
#                              // $("#imagen").hide();
#
#                              // $("div").html(data);
#                          },
#                          error: function () {
#
#                              //  $("#imagen").hide();
#                              // alert("No se ha podido cargar el archivo");
#                          }
#                      });
#                  }
#                  else {
#                      return false;
#
#                  }
#              });
#
#          });
#     </script>
# <script type="text/javascript">
#
#
#         //---------------Total area in round figure (Sq.mt.)--------------------
#
#         function ShowTblTotalArea() {
#
#             if ($('#ctl00_ContentPlaceHolder1_lblUserType').html() == 'Promoter') {
#
#                 $('#tblEditTotalArea').hide();
#                 alert('Editable By RERA');
#             }
#             else {
#                 $('#ctl00_ContentPlaceHolder1_lblTotalArea').prop('disabled', false);
#                 $('#tblEditTotalArea').show();
#                 $('#btnCloseTblTotalArea').show();
#
#             }
#         }
#
#         function CloseTblTotalArea() {
#             $('#ctl00_ContentPlaceHolder1_lblTotalArea').prop('disabled', true);
#             $('#btnCloseTblTotalArea').hide();
#             $('#tblEditTotalArea').hide();
#         }
#
#         //--------------------Project Category---------------------------------
#
#         function ShowProjectCategory() {
#
#             if ($('#ctl00_ContentPlaceHolder1_lblUserType').html() == 'Promoter') {
#
#                 $('#trnewprojectcategory').hide();
#                 alert('Editable By RERA');
#             }
#             else {
#                 if ($('#ctl00_ContentPlaceHolder1_lblProjectCategory').html() == 'Residential') {
#                     $('#ctl00_ContentPlaceHolder1_ddlnewProjectCatg').val("Commercial");
#
#                     $('#ctl00_ContentPlaceHolder1_ddlnewProjectCatg').html("");
#                     $('#ctl00_ContentPlaceHolder1_ddlnewProjectCatg').append($('<option></option>')
#                      .attr('value', "Commercial")
#                      .text("Commercial"));
#
#
#                 }
#                 else {
#                     $('#ctl00_ContentPlaceHolder1_ddlnewProjectCatg').html("");
#                     $('#ctl00_ContentPlaceHolder1_ddlnewProjectCatg').append($('<option></option>')
#                      .attr('value', "Residential")
#                      .text("Residential"));
#                     $('#ctl00_ContentPlaceHolder1_ddlnewProjectCatg').val("Residential");
#
#                 }
#                 $('#trnewprojectcategory').show();
#                 $('#lnkEditProjectCategory_Close').show();
#
#             }
#         }
#
#         function CloseProjectCategory() {
#             $('#lnkEditProjectCategory_Close').hide();
#             $('#trnewprojectcategory').hide();
#         }
#
#
#
#         //---------------Project Name--------------------
#
#         function ShowProjectName() {
#
#             if ($('#ctl00_ContentPlaceHolder1_lblUserType').html() == 'Promoter') {
#
#                 $('#tblnewprojectName').hide();
#                 alert('Editable By RERA');
#             }
#             else {
#                 $('#ctl00_ContentPlaceHolder1_lblProjectName').prop('disabled', false);
#                 $('#tblnewprojectName').show();
#                 $('#lnkProjectName_Close').show();
#
#             }
#         }
#
#         function CloseProjectName() {
#             $('#ctl00_ContentPlaceHolder1_lblProjectName').prop('disabled', true);
#             $('#lnkProjectName_Close').hide();
#             $('#tblnewprojectName').hide();
#         }
#
#
#         //---------------Project Cost--------------------
#
#         function ShowProjectCost() {
#
#             if ($('#ctl00_ContentPlaceHolder1_lblUserType').html() == 'Promoter') {
#
#                 $('#tblEditProjectCost').hide();
#                 alert('Editable By RERA');
#             }
#             else {
#                 $('#ctl00_ContentPlaceHolder1_lblProjectCost').prop('disabled', false);
#                 $('#tblEditProjectCost').show();
#                 $('#lnkEditProjCost_Close').show();
#
#             }
#         }
#
#         function CloseProjectCost() {
#             $('#ctl00_ContentPlaceHolder1_lblProjectCost').prop('disabled', true);
#             $('#lnkEditProjCost_Close').hide();
#             $('#tblEditProjectCost').hide();
#         }
#
#
#         //----------------------Revised End Date---------------------------------
#
#         function EditReviseEndDate() {
#             if ($('#ctl00_ContentPlaceHolder1_lblUserType').html() == 'Promoter') {
#
#                 $('#TableRevisedEndDate').hide();
#                 //alert('Editable By RERA');
#                 $('#ctl00_ContentPlaceHolder1_txtrevised_end_date').prop('disabled', false);
#                 $('#ctl00_ContentPlaceHolder1_lnkEditRevisedEndDatePromoter').show();
#                 $('#lnkEditrevisedEndDate_Admin_Close').hide();
#                 $('#lnkEditrevisedEndDate_Admin').hide();
#
#             }
#             else {
#                 $('#ctl00_ContentPlaceHolder1_txtrevised_end_date').prop('disabled', false);
#                 $('#lnkEditrevisedEndDate_Admin_Close').show();
#                 $('#lnkEditrevisedEndDate_Admin').show();
#                 $('#TableRevisedEndDate').show();
#                 $('#lnkEditRevisedEndDate').show();
#             }
#         }
#
#         function CloseEditReviseEndDate() {
#             $('#ctl00_ContentPlaceHolder1_txtrevised_end_date').prop('disabled', true);
#             $('#TableRevisedEndDate').hide();
#             $('#lnkEditrevisedEndDate_Admin_Close').hide();
#             $('#lnkEditRevisedEndDate').show();
#             $('#ctl00_ContentPlaceHolder1_lnkEditRevisedEndDatePromoter').hide();
#         }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         function deletePlot(id, apartmentid) {
#
#
#
#             $.ajax({
#                 type: "POST",
#                 url: "WebService1.asmx/deletePlot",
#                 data: "{id: '" + id + "',apartmentid:'" + apartmentid + "'}",
#                 contentType: "application/json; charset=utf-8",
#                 dataType: "json",
#                 success: function (r) {
#                     loadPlots();
#                 },
#                 error: function (r) {
#                     // alert(r.responseText);
#                 },
#                 failure: function (r) {
#                     // alert(r.responseText);
#                 }
#             });
#
#
#
#
#         }
#
#
#
#
#
#         function setparking() {
#             if ($('#txtFloorNo').val() == "GF") {
#
#                 $('#trparkingspace').show();
#                 $('#ContentPlaceHolder1_Text16').val("");
#
#
#
#             }
#             else {
#                 $('#trparkingspace').hide();
#
#             }
#
#         }
#
#         function setfloorno() {
#
#
#             var floors = parseInt($('#txtnooffloor').val());
#
#             $('#txtFloorNo').html("");
#
#
#
#             $('#txtFloorNo')
# .append($("<option></option>")
#            .attr("value", "0")
#            .text("Select"));
#
#             $('#txtFloorNo')
# .append($("<option></option>")
#         .attr("value", "BSMNT")
#         .text("Basement"));
#
#             $('#txtFloorNo')
# .append($("<option></option>")
#       .attr("value", "GF")
#       .text("Ground Floor"));
#
#
#
#             for (var i = 1; i <= floors; i++) {
#                 $('#txtFloorNo')
#  .append($("<option></option>")
#             .attr("value", i)
#             .text(i));
#
#
#
#             }
#
#
#         }
#
#
#
#         function checkprojectenddate() {
#
#
#             var startdate = $('#ctl00_ContentPlaceHolder1_txtPermitValidUpto').val();
#             var enddate = $('#ctl00_ContentPlaceHolder1_txtrevised_end_date').val();
#
#
#
#             var orignal_startdate = $('#ctl00_ContentPlaceHolder1_lblOriginalStartDate').val();
#             var proposed_start_date = $('#ctl00_ContentPlaceHolder1_lblStartDate').val();
#
#
#             if (startdate == "") {
#
#                 alert("Fill Valid Upto date first");
#                 $('#ctl00_ContentPlaceHolder1_txtrevised_end_date').val("");
#
#                 return;
#             }
#
#
#
#             var datePartsfrom = startdate.split("-");
#
#             var dateObjectfrom = new Date(datePartsfrom[2], datePartsfrom[1] - 1, datePartsfrom[0]);
#
#
#
#             var datePartsto = enddate.split("-");
#
#             var dateObjectto = new Date(datePartsto[2], datePartsto[1] - 1, datePartsto[0]);
#
#             var validupto = new Date(dateObjectfrom);
#             var RevisedEnddate = new Date(dateObjectto);
#
#
#
#             var orignal_startdate_1 = orignal_startdate.split("-");
#
#             var data_orignal_strdate_1 = new Date(orignal_startdate_1[2], orignal_startdate_1[1] - 1, orignal_startdate_1[0]);
#
#             var valid_data_orignal_strdate_1 = new Date(data_orignal_strdate_1);
#
#             var proposed_start_date_1 = proposed_start_date.split("-");
#             var data_proposed_start_date_1 = new Date(proposed_start_date_1[2], proposed_start_date_1[1] - 1, proposed_start_date_1[0]);
#
#             var valid_data_proposed_start_date_1 = new Date(data_proposed_start_date_1);
#
#
#
#             if (valid_data_orignal_strdate_1 != "") {
#
#                 if (valid_data_orignal_strdate_1 > RevisedEnddate) {
#                     alert("Revised end date can not be less then Orignal date of permit/ sanctioned letter");
#                     $('#ctl00_ContentPlaceHolder1_txtrevised_end_date').val("");
#                     return;
#                 }
#             }
#
#             if (valid_data_proposed_start_date_1 != "") {
#
#
#                 if (valid_data_proposed_start_date_1 > RevisedEnddate) {
#                     alert("Revised end date can not be less then Proposed Start Date of permit/ sanctioned letter");
#                     $('#ctl00_ContentPlaceHolder1_txtrevised_end_date').val("");
#                     return;
#                 }
#             }
#
#             if (RevisedEnddate > validupto) {
#
#
#                 alert("Revised end date can not be beyond date of validity of permit/ sanctioned letter");
#
#                 $('#ctl00_ContentPlaceHolder1_txtrevised_end_date').val("");
#
#                      return;
#
#
#
#                  }
#
#
#
#
#
#              }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#              function saveApartment() {
#
#
#
#                  // var id = getParameterByName('lblProjectId');
#                  var id = '918';
#                  var blockno = $('#txtBlock').val();
#                  var floorno = $('#txtFloorNo').val();
#                  var type = $('#ddltypeofapartment').val();
#                  var NoOfapartment = $('#txtNoOfFlats').val();
#                  var unitArea = $('#txtCarpetArea').val();
#                  var noOfbalcony = $('#txtNoOfBalcony').val();
#                  var totalAreaBalcony = $('#txtAreaOfBalcony').val();
#                  var noOfverandah = $('#txtNoOFBaramda').val();
#                  var totalAreaverandah = $('#txtAreaOfBaramda').val();
#                  var initialUnitCost = $('#txtCurrentunitCost').val();
#                  var unitCost = $('#txtTotalCost').val();
#                  var rateOfIntrest = $('#txtRateofInterest').val();
#                  var noOfGarriage = $('#txtNoOfGarriage').val();
#                  var areaOfGarriage = $('#txtAreaOfGarriage').val();
#                  var openParkingSpace = $('#txtopenParkingSpace').val();
#                  var gettype = $('#ctl00_ContentPlaceHolder1_ddlgettype').val();
#                  var numberoffloor = $('#txtnooffloor').val();
#
#                  if (blockno == "") {
#
#                      alert("Fill Block/Tower Name/ No");
#                      return false;
#                  }
#                  if (numberoffloor == "") {
#
#                      alert("Fill No of floors");
#                      return false;
#                  }
#
#
#
#
#                  if (floorno == "0") {
#
#                      alert("Select Floor no.");
#                      return false;
#                  }
#                  if (type == "0") {
#
#                      alert("Select Type of Flat/ Apartment/ Shop");
#                      return false;
#                  }
#                  if (NoOfapartment == "") {
#
#                      alert("Fill Number of Apartment/Flats");
#                      return false;
#                  }
#                  if (unitArea == "") {
#
#                      alert("Fill Unit Carpet Area (in sqm)");
#                      return false;
#                  }
#                  if (noOfbalcony == "") {
#
#                      alert("Fill Number of Balcony");
#                      return false;
#                  }
#                  if (totalAreaBalcony == "") {
#
#                      alert("Fill Total Area of Balcony");
#                      return false;
#                  }
#                  if (noOfverandah == "") {
#
#                      alert("Fill Number of Verandah");
#                      return false;
#                  }
#                  if (totalAreaverandah == "") {
#
#                      alert("Fill Total Area of Verandah");
#                      return false;
#                  }
#                  if (initialUnitCost == "") {
#
#                      alert("Fill Initial Unit Cost");
#                      return false;
#                  }
#                  if (unitCost == "") {
#
#                      alert("Fill Unit Cost");
#                      return false;
#                  }
#                  if (rateOfIntrest == "") {
#
#                      alert("Fill Rate of Interest ");
#                      return false;
#                  }
#                  if (noOfGarriage == "") {
#
#                      alert("Fill No. of garrage ");
#                      return false;
#                  }
#                  if (areaOfGarriage == "") {
#
#                      alert("Fill Total Area of garage (in sqm) ");
#                      return false;
#                  }
#                  if (openParkingSpace == "") {
#
#                      alert("Fill Open Parking Space (in Nos.) ");
#                      return false;
#                  }
#
#
#
#
#                  $.ajax({
#                      type: "POST",
#                      url: "WebService1.asmx/saveApartmentTransaction",
#                      data: "{id: '" + id + "', blockno: '" + blockno + "', floorno: '" + floorno + "', type: '" + type + "', NoOfapartment: '" + NoOfapartment + "', unitArea: '" + unitArea + "', noOfbalcony: '" + noOfbalcony + "', totalAreaBalcony: '" + totalAreaBalcony + "', noOfverandah: '" + noOfverandah + "', totalAreaverandah: '" + totalAreaverandah + "', unitCost: '" + unitCost + "', rateOfIntrest: '" + rateOfIntrest + "',noOfGarriage: '" + noOfGarriage + "',areaOfGarriage: '" + areaOfGarriage + "',openParkingSpace: '" + openParkingSpace + "',gettype: '" + gettype + "',numberoffloor: '" + numberoffloor + "'}",
#                      contentType: "application/json; charset=utf-8",
#                      dataType: "json",
#                      success: function (r) {
#
#
#                          alert('Added Successfully');
#
#                          loadApartment();
#
#                          $("#txtNoOfFlats").val("");
#                          $("#txtCarpetArea").val("");
#                          $("#txtNoOfBalcony").val("");
#                          $("#txtAreaOfBalcony").val("");
#                          $("#txtNoOFBaramda").val("");
#
#                          $("#txtAreaOfBaramda").val("");
#                          $("#Text14").val("");
#                          $("#txtAreaOfGarriage").val("");
#                          $("#txtNoOfGarriage").val("");
#
#                          //  $('#Table1').show();
#
#
#                          ///  $('#Table1').html(r.d);
#
#
#                      },
#                      error: function (r) {
#                          alert(r.responseText);
#                      },
#                      failure: function (r) {
#                          alert(r.responseText);
#                      }
#                  });
#
#
#
#
#              }
#
#
#
#
#
#
#              $(document).ready(function () {
#
#                  $('#ctl00_ContentPlaceHolder1_File_ApprovedLayout').bind('change', function () {
#
#                 var filename = $('#ctl00_ContentPlaceHolder1_File_ApprovedLayout').val().split('\\').pop();
#
#
#                 //alert(filename);
#                 var extension = filename.substring(filename.lastIndexOf('.') + 1);
#                 //alert(extension);
#                 if (extension !== "jpg" && extension !== "jpeg" && extension !== "png" && extension !== "pdf" && extension !== "JPG" && extension !== "JPEG" && extension !== "PNG" && extension !== "PDF") {
#                     $('#ctl00_ContentPlaceHolder1_File_ApprovedLayout').val(null);
#                     alert("Only JPG,PNG and PDF files allowed  ");
#                 }
#                 if (this.files[0].size > 2097152) {
#                     $('#ctl00_ContentPlaceHolder1_File_ApprovedLayout').val(null);
#
#                     alert("File size must 2mb or below ");
#                 } else {
#
#                 }
#             });
#
#         });
#
#         $(document).ready(function () {
#
#             $('#ctl00_ContentPlaceHolder1_File_SanctionedLetter').bind('change', function () {
#
#
#
#                     var filename = $('#ctl00_ContentPlaceHolder1_File_SanctionedLetter').val().split('\\').pop();
#
#
#                     //alert(filename);
#                     var extension = filename.substring(filename.lastIndexOf('.') + 1);
#                     //alert(extension);
#                     if (extension !== "jpg" && extension !== "jpeg" && extension !== "png" && extension !== "pdf" && extension !== "JPG" && extension !== "JPEG" && extension !== "PNG" && extension !== "PDF") {
#                         $('#ctl00_ContentPlaceHolder1_File_SanctionedLetter').val(null);
#                     alert("Only JPG,PNG and PDF files allowed  ");
#                 }
#                     if (this.files[0].size > 2097152) {
#                         $('#ctl00_ContentPlaceHolder1_File_SanctionedLetter').val(null);
#
#                     alert("File size must 2mb or below ");
#                 } else {
#
#                 }
#                 });
#
#             });
#
#
#         $(document).ready(function () {
#
#             $('#ctl00_ContentPlaceHolder1_File_ApprovedMap').bind('change', function () {
#
#
#
#                    var filename = $('#ctl00_ContentPlaceHolder1_File_ApprovedMap').val().split('\\').pop();
#
#
#                    //alert(filename);
#                    var extension = filename.substring(filename.lastIndexOf('.') + 1);
#                    //alert(extension);
#                    if (extension !== "jpg" && extension !== "jpeg" && extension !== "png" && extension !== "pdf" && extension !== "JPG" && extension !== "JPEG" && extension !== "PNG" && extension !== "PDF") {
#                        $('#ctl00_ContentPlaceHolder1_File_ApprovedMap').val(null);
#                     alert("Only JPG,PNG and PDF files allowed  ");
#                 }
#                    if (this.files[0].size > 2097152) {
#                        $('#ctl00_ContentPlaceHolder1_File_ApprovedMap').val(null);
#
#                     alert("File size must 2mb or below ");
#                 } else {
#
#                 }
#                });
#
#            });
#
#         $(document).ready(function () {
#
#             $('#ctl00_ContentPlaceHolder1_FileFloorPlanOfAllTypes').bind('change', function () {
#
#
#
#                    var filename = $('#ctl00_ContentPlaceHolder1_FileFloorPlanOfAllTypes').val().split('\\').pop();
#
#
#                    //alert(filename);
#                    var extension = filename.substring(filename.lastIndexOf('.') + 1);
#                    //alert(extension);
#                    if (extension !== "jpg" && extension !== "jpeg" && extension !== "png" && extension !== "pdf" && extension !== "JPG" && extension !== "JPEG" && extension !== "PNG" && extension !== "PDF") {
#                        $('#ctl00_ContentPlaceHolder1_FileFloorPlanOfAllTypes').val(null);
#                     alert("Only JPG,PNG and PDF files allowed  ");
#                 }
#
#
#                    if (this.files[0].size > 2097152) {
#                        $('#ctl00_ContentPlaceHolder1_FileFloorPlanOfAllTypes').val(null);
#
#                     alert("File size must 2mb or below ");
#                 } else {
#
#                 }
#                });
#
#            });
#
#         $(document).ready(function () {
#
#             $('#ctl00_ContentPlaceHolder1_FileProjectSpecification').bind('change', function () {
#
#
#
#                    var filename = $('#ctl00_ContentPlaceHolder1_FileProjectSpecification').val().split('\\').pop();
#
#
#                    //alert(filename);
#                    var extension = filename.substring(filename.lastIndexOf('.') + 1);
#                    //alert(extension);
#                    if (extension !== "jpg" && extension !== "jpeg" && extension !== "png" && extension !== "pdf" && extension !== "JPG" && extension !== "JPEG" && extension !== "PNG" && extension !== "PDF") {
#                        $('#ctl00_ContentPlaceHolder1_FileProjectSpecification').val(null);
#                     alert("Only JPG,PNG and PDF files allowed  ");
#                 }
#
#
#                    if (this.files[0].size > 2097152) {
#                        $('#ctl00_ContentPlaceHolder1_FileProjectSpecification').val(null);
#
#                     alert("File size must 2mb or below ");
#                 } else {
#
#                 }
#                });
#
#            });
#
#
#
#         $(document).ready(function () {
#
#             $('#ctl00_ContentPlaceHolder1_fileUploadRegistryDoc').bind('change', function () {
#
#                    var filename = $('#ctl00_ContentPlaceHolder1_fileUploadRegistryDoc').val().split('\\').pop();
#
#
#                    //alert(filename);
#                    var extension = filename.substring(filename.lastIndexOf('.') + 1);
#                    //alert(extension);
#                    if (extension !== "jpg" && extension !== "jpeg" && extension !== "png" && extension !== "pdf" && extension !== "JPG" && extension !== "JPEG" && extension !== "PNG" && extension !== "PDF") {
#                        $('#ctl00_ContentPlaceHolder1_fileUploadRegistryDoc').val(null);
#                     alert("Only JPG,PNG and PDF files allowed  ");
#                 }
#
#
#
#
#                    if (this.files[0].size > 2097152) {
#                        $('#ctl00_ContentPlaceHolder1_fileUploadRegistryDoc').val(null);
#
#                     alert("Files maximum size of 2 MB allowed");
#                 } else {
#
#                 }
#                });
#
#            });
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         function savekhasra() {
#             var id = '918';
#             var khasrano = $('#khasrano').val();
#             var area = $('#area').val();
#             var khasraType = $('#SelectKhasra').val();
#
#
#
#             var data = new FormData();
#
#
#
#
#             data.append("id", id);
#             data.append("khasrano", khasrano);
#             data.append("area", area);
#             data.append("khasraType", khasraType);
#
#             if (khasrano == "") {
#
#                 alert("Add Khasra Number");
#                 return false;
#
#
#             }
#             if (area == "") {
#
#                 alert("Add Area");
#                 return false;
#             }
#             if (khasraType == "0") {
#
#                 alert("Please Select Khasra/Plot type");
#                 return false;
#             }
#
#
#             $.ajax({
#                 type: "POST",
#                 url: "WebService1.asmx/addkhasra",
#                 // data: data,
#                 data: "{id: '" + id + "', khasrano: '" + khasrano + "', area: '" + area + "', khasraType: '" + khasraType + "'}",
#                 contentType: false,
#                 contentType: 'application/json; charset=utf-8',
#                 dataType: 'json',
#                 // processData: false,
#                 success: function (r) {
#                     // alert(r.d);
#                     //alert("Record Save Successfully");
#
#                     $('#khasrano').val("");
#                     $('#area').val("");
#
#                     addkhasra();
#
#                 },
#                 error: function (r) {
#                     alert(r.responseText);
#                 },
#                 failure: function (r) {
#                     alert(r.responseText);
#                 }
#             });
#
#
#
#
#         }
#
#
#
#         function deleteKhasra(id, khasraid) {
#
#             $.ajax({
#                 type: "POST",
#                 url: "WebService1.asmx/deleteKhasra",
#                 data: "{id: '" + id + "',khasraid:'" + khasraid + "'}",
#                 contentType: "application/json; charset=utf-8",
#                 dataType: "json",
#                 success: function (r) {
#                     // alert(r.d);
#                     // $('#dbkhasradetails').html(r.d);
#                     addkhasra();
#                 },
#                 error: function (r) {
#                     alert(r.responseText);
#                 },
#                 failure: function (r) {
#                     alert(r.responseText);
#                 }
#             });
#
#         }
#
#
#         $(document).ready(function () {
#             addkhasra();
#             loaddocs();
#
#         });
#
#
#         $(function () {
#             $("#ctl00_ContentPlaceHolder1_ddl_docstype").change(function () {
#                 // var selectedText = $(this).find("option:selected").text();
#
#                 var selectedValue = $(this).val();
#
#
#                 if (selectedValue == 'z') {
#                     $("#lblname").text("");
#                     $("#lbldate").text("");
#                     $("#txtdate_docs").hide();
#                     $("#txtno").hide();
#
#                 }
#                 else if (selectedValue == 'R') {
#                     $("#lblname").text("Registry Number *");
#                     $("#lbldate").text("Date");
#                     $("#txtdate_docs").show();
#                     $("#txtno").show();
#                 }
#                 else if (selectedValue == 'S') {
#                     $("#lblname").text("Sale Deed No *");
#                     $("#lbldate").text("Date");
#                     $("#txtdate_docs").show();
#                     $("#txtno").show();
#                 }
#                 else if (selectedValue == 'L') {
#                     $("#lblname").text("Lease Deed No *");
#                     $("#lbldate").text("Date");
#                     $("#txtdate_docs").show();
#                     $("#txtno").show();
#                 }
#                 else if (selectedValue == 'E') {
#                     $("#lblname").text("Khatauni Fasli Year *");
#                     $("#lbldate").text("");
#                     $("#txtdate_docs").hide();
#                     $("#txtno").show();
#                 }
#                 else if (selectedValue == 'A') {
#                     $("#lblname").text("Allotment Letter No *");
#                     $("#lbldate").text("Date");
#                     $("#txtdate_docs").show();
#                     $("#txtno").show();
#
#                 }
#
#             });
#
#         });
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             function upload_docs() {
#                 var txt = $("#ctl00_ContentPlaceHolder1_ddl_docstype").val();
#
#                 if (txt == 'z') {
#                     alert("Please Select Related Documents");
#                     return;
#                 }
#                 else if ($('#ctl00_ContentPlaceHolder1_fileUploadRegistryDoc').val() == "") {
#                         alert("Please Choose file");
#                         return;
#                     }
#
#                     else if ($("#txtno").val() == "") {
#
#
#                         alert("Fill " + $("#lblname").html())
#
#                         return;
#                     }
#
#
#
#
#                     var id = '918';
#
#
#
#                 var selectedText = $("#ctl00_ContentPlaceHolder1_ddl_docstype").find("option:selected").text();
#
#                 // var doctype = $('#lblname').val();
#                 var name = $('#txtno').val();
#
#                 var date = $('#txtdate_docs').val();
#
#
#
#
#                 var fileUpload = $('#ctl00_ContentPlaceHolder1_fileUploadRegistryDoc').get(0);
#             var files = fileUpload.files;
#             var data = new FormData();
#             for (var i = 0; i < files.length; i++) {
#                 data.append(files[i].name, files[i]);
#             }
#             data.append("id", id);
#             data.append("date", date);
#             data.append("name", name);
#             data.append("type", selectedText);
#             $("#imagen").show();
#             $.ajax({
#                 type: "POST",
#                 url: "WebService1.asmx/upload_file",
#                 data: data,
#                 contentType: false,
#                 //dataType: "json",
#                 processData: false,
#                 success: function (r) {
#                     //  alert(r.d);
#
#                     $("#ctl00_ContentPlaceHolder1_ddl_docstype").prop('selectedIndex', 0);
#
#
#                     //$('#lblname').val("");
#                     //$('#lbldate').val("");
#                     //$('#txtno').val("");
#                     //$('#txtdate_docs').val("");
#
#                     $("#lblname").text("");
#                     $("#lbldate").text("");
#                     $("#txtdate_docs").hide();
#                     $("#txtno").hide();
#
#                     $('#tbldocs').html(r.d);
#                     loaddocs();
#                     $("#imagen").hide();
#                 },
#                 error: function (r) {
#                     alert(r.responseText);
#                 },
#                 failure: function (r) {
#                     alert(r.responseText);
#                 }
#             });
#             }
#
#
#
#             function addkhasra() {
#                 var id = '918' //getParameterByName('id');
#                 $.ajax({
#                     type: "POST",
#                     url: "WebService1.asmx/loadkhasra_In_Project_View",
#                     data: "{id: '" + id + "'}",
#                     contentType: "application/json; charset=utf-8",
#                     dataType: "json",
#                     success: function (r) {
#                         // alert(r.d);
#                         $('#dbkhasradetails').html(r.d);
#
#
#                     },
#                     error: function (r) {
#                         // alert(r.responseText);
#                     },
#                     failure: function (r) {
#                         // alert(r.responseText);
#                     }
#                 });
#
#
#
#
#
#             }
#
#
#
#             function loaddocs() {
#                 var id = '918';
#                 $.ajax({
#                     type: "POST",
#                     url: "WebService1.asmx/loaddocsNew",
#                     data: "{id: '" + id + "'}",
#                     contentType: "application/json; charset=utf-8",
#                     dataType: "json",
#                     success: function (r) {
#                         // alert(r.d);
#                         $('#tbldocs').html(r.d);
#
#
#                     },
#                     error: function (r) {
#                         alert(r.responseText);
#                     },
#                     failure: function (r) {
#                         alert(r.responseText);
#                     }
#                 });
#
#             }
#
#
#
#
#
#
#             function getpropertytype1() {
#
#
#                 document.getElementById('ctl00_ContentPlaceHolder1_hdnddlgettype').value = $('#ctl00_ContentPlaceHolder1_ddlgettype').val();
#                 var v1 = document.getElementById('ctl00_ContentPlaceHolder1_hdnddlgettype').value;
#
#
#
#                 if ($('#ctl00_ContentPlaceHolder1_ddlgettype').val() == "0") {
#
#
#
#
#                     $('#tblPlotDetails').hide();
#                     $('#tblapartment').hide();
#                     $('#ctl00_ContentPlaceHolder1_permitsection').hide();
#                 $('#ctl00_ContentPlaceHolder1_btnSanctionedPlan').hide();
#                 $('#ctl00_ContentPlaceHolder1_btnSanctionSaveAndContinue').hide();
#                 alert("select Property type");
#                 return;
#             }
#
#             else {
#
#                 $('#ctl00_ContentPlaceHolder1_permitsection').show();
#                 $('#ctl00_ContentPlaceHolder1_btnSanctionedPlan').show();
#                 $('#ctl00_ContentPlaceHolder1_btnSanctionSaveAndContinue').show();
#
#
#
#                 if ($('#ctl00_ContentPlaceHolder1_ddlgettype').val() == "AFS") {
#
#                     $('#tr_floorplanofalltype').show();
#                     loadApartment();
#
#
#
#
#                     $('#tbllanddetails').hide();
#
#
#                     $.ajax({
#                         type: "POST",
#                         url: "WebService1.asmx/selectpropertytype",
#                         data: "{type: '" + $('#ctl00_ContentPlaceHolder1_ddlgettype').val() + "'}",
#                         contentType: "application/json; charset=utf-8",
#                         dataType: "json",
#                         success: function (r) {
#
#                             $('#tblapartment').show();
#                             $('#tblPlotDetails').hide();
#                             $('#ddltypeofapartment').html(r.d);
#                         },
#                         error: function (r) {
#                             // alert(r.responseText);
#                         },
#                         failure: function (r) {
#                             // alert(r.responseText);
#                         }
#                     });
#
#
#
#                 }
#                 else if ($('#ctl00_ContentPlaceHolder1_ddlgettype').val() == "Plot") {
#                     $('#tbllanddetails').hide();
#                     $('#tr_floorplanofalltype').hide();
#                     loadPlots();
#                     $.ajax({
#                         type: "POST",
#                         url: "WebService1.asmx/selectpropertytype",
#                         data: "{type: '" + $('#ctl00_ContentPlaceHolder1_ddlgettype').val() + "'}",
#                         contentType: "application/json; charset=utf-8",
#                         dataType: "json",
#                         success: function (r) {
#                             // alert(r.d);
#                             $('#tblPlotDetails').show();
#                             $('#tblapartment').hide();
#                             $('#ddltypeofplot').html(r.d);
#                         },
#                         error: function (r) {
#                             // alert(r.responseText);
#                         },
#                         failure: function (r) {
#                             // alert(r.responseText);
#                         }
#                     });
#
#
#
#                 }
#                 else if ($('#ctl00_ContentPlaceHolder1_ddlgettype').val() == "villa") {
#                     //alert('ok');
#                     $('#tbllanddetails').hide();
#                     $('#tr_floorplanofalltype').hide();
#                     //loadPlots();
#                     $('#tblapartment').hide();
#
#                     loadVillas();
#
#                     $('#ctl00_ContentPlaceHolder1_permitsection').show();
#                     $('#ddlgettyperow').show();
#                 }
#
#
#
#
#
#
#     }
#                 //savekhasra()
#
#
#
# }
#
#
#
#
# function loadVillas() {
#
#
#     var id = $('#ctl00_ContentPlaceHolder1_HF_ID').val();
#             // alert('ok'+id);
#             $.ajax({
#                 type: "POST",
#                 url: "WebService1.asmx/loadVillasnew",
#                 data: "{id: '" + id + "'}",
#                 contentType: "application/json; charset=utf-8",
#                 dataType: "json",
#                 success: function (r) {
#                     //   alert(r.d);
#
#                    $('#ShowTableApartment').show();
#                     $('#ShowTableApartment').html(r.d);
#
#                     // $('#ShowTablePlots').hide();
#
#                 },
#                 error: function (r) {
#                     alert(r.responseText);
#                 },
#                 failure: function (r) {
#                     alert(r.responseText);
#                 }
#             });
#
#         }
#
#
#         function loadVillas_Mix() {
#
#
#             var id = $('#ctl00_ContentPlaceHolder1_HF_ID').val();
#             // alert('ok'+id);
#             $.ajax({
#                 type: "POST",
#                 url: "WebService1.asmx/loadVilla_Mix",
#                 data: "{id: '" + id + "'}",
#                 contentType: "application/json; charset=utf-8",
#                 dataType: "json",
#                 success: function (r) {
#                     //   alert(r.d);
#
#
#
#                     $('#ShowTablePlots').show();
#
#
#                     $('#ShowTablePlots').html(r.d);
#
#                     // $('#ShowTablePlots').hide();
#
#                 },
#                 error: function (r) {
#                     alert(r.responseText);
#                 },
#                 failure: function (r) {
#                     alert(r.responseText);
#                 }
#             });
#
#         }
#
#
#
#         function showpermitsection() {
#
#             $('#ctl00_ContentPlaceHolder1_btn_addmorepermit').hide();
#         $('#ctl00_ContentPlaceHolder1_btnSanctionedPlan').show();
#         $('#ctl00_ContentPlaceHolder1_permitsection').show();
#         $('#ctl00_ContentPlaceHolder1_txtPermitNo').val("");
# ...
# <script src="js/contact.js"></script>
# <script src="js/jquery.form.js"></script>
# <script src="js/jquery.validate.min.js"></script>
# <script src="js/mail-script.js"></script>
# <script src="js/theme.js"></script>
# <script src="js/bootstrap-multiselect.js"></script>
# <script src="js/jquery-ui.min-1.9.1.js" type="text/javascript"></script>
# <script src="multiselect/bootstrap-multiselect.js"></script>
# <script src="js/jquery.easy-ticker.min.js"></script>
# <script src="js/jquery.easing.min.js"></script>
# <script src="js/custom.js"></script>
# <script type="text/javascript">
# //<![CDATA[
# var Page_Validators =  new Array(document.getElementById("ctl00_ContentPlaceHolder1_RequiredFieldValidator7"), document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvBlockNoInsert"), document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFloorNoInsert"), document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFlatTypeInsert"), document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfFlatsInsert"), document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvCarpetAreaInsert"), document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOFBalconyInsert"), document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfbalconyInsert"), document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfBarandaInsert"), document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfBarandaInsert"), document.getElementById("ctl00_ContentPlaceHolder1_RegularExpressionValidator1"));
# //]]>
# </script>
# <script type="text/javascript">
# //<![CDATA[
# var ctl00_ContentPlaceHolder1_RequiredFieldValidator7 = document.all ? document.all["ctl00_ContentPlaceHolder1_RequiredFieldValidator7"] : document.getElementById("ctl00_ContentPlaceHolder1_RequiredFieldValidator7");
# ctl00_ContentPlaceHolder1_RequiredFieldValidator7.controltovalidate = "ctl00_ContentPlaceHolder1_ddlAuthority";
# ctl00_ContentPlaceHolder1_RequiredFieldValidator7.focusOnError = "t";
# ctl00_ContentPlaceHolder1_RequiredFieldValidator7.errormessage = "Select Competant Authority";
# ctl00_ContentPlaceHolder1_RequiredFieldValidator7.evaluationfunction = "RequiredFieldValidatorEvaluateIsValid";
# ctl00_ContentPlaceHolder1_RequiredFieldValidator7.initialvalue = "";
# var ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvBlockNoInsert = document.all ? document.all["ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvBlockNoInsert"] : document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvBlockNoInsert");
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvBlockNoInsert.controltovalidate = "ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_txtBlockNoInsert";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvBlockNoInsert.validationGroup = "validaiton";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvBlockNoInsert.evaluationfunction = "RequiredFieldValidatorEvaluateIsValid";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvBlockNoInsert.initialvalue = "";
# var ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFloorNoInsert = document.all ? document.all["ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFloorNoInsert"] : document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFloorNoInsert");
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFloorNoInsert.controltovalidate = "ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_txtFloorNoInsert";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFloorNoInsert.validationGroup = "validaiton";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFloorNoInsert.evaluationfunction = "RequiredFieldValidatorEvaluateIsValid";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFloorNoInsert.initialvalue = "";
# var ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFlatTypeInsert = document.all ? document.all["ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFlatTypeInsert"] : document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFlatTypeInsert");
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFlatTypeInsert.controltovalidate = "ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_txtFlatTypeInsert";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFlatTypeInsert.validationGroup = "validaiton";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFlatTypeInsert.evaluationfunction = "RequiredFieldValidatorEvaluateIsValid";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFlatTypeInsert.initialvalue = "";
# var ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfFlatsInsert = document.all ? document.all["ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfFlatsInsert"] : document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfFlatsInsert");
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfFlatsInsert.controltovalidate = "ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_txtNoOfFlatsInsert";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfFlatsInsert.validationGroup = "validaiton";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfFlatsInsert.evaluationfunction = "RequiredFieldValidatorEvaluateIsValid";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfFlatsInsert.initialvalue = "";
# var ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvCarpetAreaInsert = document.all ? document.all["ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvCarpetAreaInsert"] : document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvCarpetAreaInsert");
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvCarpetAreaInsert.controltovalidate = "ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_txtCarpetAreaInsert";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvCarpetAreaInsert.validationGroup = "validaiton";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvCarpetAreaInsert.evaluationfunction = "RequiredFieldValidatorEvaluateIsValid";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvCarpetAreaInsert.initialvalue = "";
# var ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOFBalconyInsert = document.all ? document.all["ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOFBalconyInsert"] : document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOFBalconyInsert");
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOFBalconyInsert.controltovalidate = "ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_txtNoOFBalconyInsert";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOFBalconyInsert.validationGroup = "validaiton";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOFBalconyInsert.evaluationfunction = "RequiredFieldValidatorEvaluateIsValid";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOFBalconyInsert.initialvalue = "";
# var ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfbalconyInsert = document.all ? document.all["ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfbalconyInsert"] : document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfbalconyInsert");
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfbalconyInsert.controltovalidate = "ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_txtAreaOfbalconyInsert";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfbalconyInsert.validationGroup = "validaiton";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfbalconyInsert.evaluationfunction = "RequiredFieldValidatorEvaluateIsValid";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfbalconyInsert.initialvalue = "";
# var ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfBarandaInsert = document.all ? document.all["ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfBarandaInsert"] : document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfBarandaInsert");
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfBarandaInsert.controltovalidate = "ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_txtNoOfBarandaInsert";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfBarandaInsert.validationGroup = "validaiton";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfBarandaInsert.evaluationfunction = "RequiredFieldValidatorEvaluateIsValid";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfBarandaInsert.initialvalue = "";
# var ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfBarandaInsert = document.all ? document.all["ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfBarandaInsert"] : document.getElementById("ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfBarandaInsert");
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfBarandaInsert.controltovalidate = "ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_txtAreaOfBarandaInsert";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfBarandaInsert.validationGroup = "validaiton";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfBarandaInsert.evaluationfunction = "RequiredFieldValidatorEvaluateIsValid";
# ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfBarandaInsert.initialvalue = "";
# var ctl00_ContentPlaceHolder1_RegularExpressionValidator1 = document.all ? document.all["ctl00_ContentPlaceHolder1_RegularExpressionValidator1"] : document.getElementById("ctl00_ContentPlaceHolder1_RegularExpressionValidator1");
# ctl00_ContentPlaceHolder1_RegularExpressionValidator1.controltovalidate = "ctl00_ContentPlaceHolder1_fileUploadRegistryDoc";
# ctl00_ContentPlaceHolder1_RegularExpressionValidator1.errormessage = "Only JPG,PNG and PDF files allowed";
# ctl00_ContentPlaceHolder1_RegularExpressionValidator1.evaluationfunction = "RegularExpressionValidatorEvaluateIsValid";
# ctl00_ContentPlaceHolder1_RegularExpressionValidator1.validationexpression = "(.*?)\\.(pdf|PDF|jpg|JPG|jpeg|JPEG|png|PNG)$";
# //]]>
# </script>
# <script type="text/javascript">new Sys.WebForms.Menu({ element: 'ctl00_menuBar', disappearAfter: 500, orientation: 'horizontal', tabIndex: 0, disabled: false });</script>
# <script type="text/javascript">
# //<![CDATA[
#
# var Page_ValidationActive = false;
# if (typeof(ValidatorOnLoad) == "function") {
#     ValidatorOnLoad();
# }
#
# function ValidatorOnSubmit() {
#     if (Page_ValidationActive) {
#         return ValidatorCommonOnSubmit();
#     }
#     else {
#         return true;
#     }
# }
#         Sys.Application.add_init(function() {
#     $create(Sys.Extended.UI.CalendarBehavior, {"cssClass":" cal_Theme1","format":"dd-MM-yyyy","id":"ctl00_ContentPlaceHolder1_CalendarExtender12"}, null, null, $get("ctl00_ContentPlaceHolder1_txtTotalArea_OrderDate"));
# });
# Sys.Application.add_init(function() {
#     $create(Sys.Extended.UI.CalendarBehavior, {"cssClass":" cal_Theme1","format":"dd-MM-yyyy","id":"ctl00_ContentPlaceHolder1_CalendarExtender5"}, null, null, $get("ctl00_ContentPlaceHolder1_txtOrderDate"));
# });
# Sys.Application.add_init(function() {
#     $create(Sys.Extended.UI.CalendarBehavior, {"cssClass":" cal_Theme1","format":"dd-MM-yyyy","id":"ctl00_ContentPlaceHolder1_CalendarExtender9"}, null, null, $get("ctl00_ContentPlaceHolder1_txtOrderDateForProjectName"));
# });
# Sys.Application.add_init(function() {
#     $create(Sys.Extended.UI.CalendarBehavior, {"cssClass":" cal_Theme1","format":"dd-MM-yyyy","id":"ctl00_ContentPlaceHolder1_CalendarExtender1"}, null, null, $get("ctl00_ContentPlaceHolder1_lblOriginalStartDate"));
# });
#
# document.getElementById('ctl00_ContentPlaceHolder1_RequiredFieldValidator7').dispose = function() {
#     Array.remove(Page_Validators, document.getElementById('ctl00_ContentPlaceHolder1_RequiredFieldValidator7'));
# }
# Sys.Application.add_init(function() {
#     $create(Sys.Extended.UI.CalendarBehavior, {"cssClass":" cal_Theme1","format":"dd-MM-yyyy","id":"ctl00_ContentPlaceHolder1_CalendarExtender11"}, null, null, $get("ctl00_ContentPlaceHolder1_txtProjectCost_OrderDate"));
# });
# Sys.Application.add_init(function() {
#     $create(Sys.Extended.UI.CalendarBehavior, {"cssClass":" cal_Theme1","format":"dd-MM-yyyy","id":"ctl00_ContentPlaceHolder1_CalendarExtender3"}, null, null, $get("ctl00_ContentPlaceHolder1_lblPermitDate"));
# });
# Sys.Application.add_init(function() {
#     $create(Sys.Extended.UI.CalendarBehavior, {"cssClass":" cal_Theme1","format":"dd/MM/yyyy","id":"ctl00_ContentPlaceHolder1_CalendarExtenderPermitDate"}, null, null, $get("ctl00_ContentPlaceHolder1_txtPermitDate"));
# });
# Sys.Application.add_init(function() {
#     $create(Sys.Extended.UI.CalendarBehavior, {"cssClass":" cal_Theme1","format":"dd-MM-yyyy","id":"ctl00_ContentPlaceHolder1_CalendarExtender10"}, null, null, $get("ctl00_ContentPlaceHolder1_txtRevalidatedPermitDate"));
# });
# Sys.Application.add_init(function() {
#     $create(Sys.Extended.UI.CalendarBehavior, {"cssClass":" cal_Theme1","format":"dd-MM-yyyy","id":"ctl00_ContentPlaceHolder1_CalendarExtender6"}, null, null, $get("ctl00_ContentPlaceHolder1_txtPermitValidUpto"));
# });
# Sys.Application.add_init(function() {
#     $create(Sys.Extended.UI.CalendarBehavior, {"cssClass":" cal_Theme1","format":"dd-MM-yyyy","id":"ctl00_ContentPlaceHolder1_ajaxcalrevisedenddate"}, null, null, $get("ctl00_ContentPlaceHolder1_txtrevised_end_date"));
# });
# Sys.Application.add_init(function() {
#     $create(Sys.Extended.UI.CalendarBehavior, {"cssClass":" cal_Theme1","format":"dd-MM-yyyy","id":"ctl00_ContentPlaceHolder1_CalendarExtender7"}, null, null, $get("ctl00_ContentPlaceHolder1_txtOrderDateRevisedEndDate"));
# });
#
# document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvBlockNoInsert').dispose = function() {
#     Array.remove(Page_Validators, document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvBlockNoInsert'));
# }
#
# document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFloorNoInsert').dispose = function() {
#     Array.remove(Page_Validators, document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFloorNoInsert'));
# }
#
# document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFlatTypeInsert').dispose = function() {
#     Array.remove(Page_Validators, document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvFlatTypeInsert'));
# }
#
# document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfFlatsInsert').dispose = function() {
#     Array.remove(Page_Validators, document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfFlatsInsert'));
# }
#
# document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvCarpetAreaInsert').dispose = function() {
#     Array.remove(Page_Validators, document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvCarpetAreaInsert'));
# }
#
# document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOFBalconyInsert').dispose = function() {
#     Array.remove(Page_Validators, document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOFBalconyInsert'));
# }
#
# document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfbalconyInsert').dispose = function() {
#     Array.remove(Page_Validators, document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfbalconyInsert'));
# }
#
# document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfBarandaInsert').dispose = function() {
#     Array.remove(Page_Validators, document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvNoOfBarandaInsert'));
# }
#
# document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfBarandaInsert').dispose = function() {
#     Array.remove(Page_Validators, document.getElementById('ctl00_ContentPlaceHolder1_GrdApartmentEdit_ctl31_rfvAreaOfBarandaInsert'));
# }
#
# document.getElementById('ctl00_ContentPlaceHolder1_RegularExpressionValidator1').dispose = function() {
#     Array.remove(Page_Validators, document.getElementById('ctl00_ContentPlaceHolder1_RegularExpressionValidator1'));
# }
# //]]>
# </script>
# </form>
# </body></html>

# %%
TARGET_DIR = f'/home/anm/Downloads/'

# iterate over all tables
filepath = "{}up.xlsx".format(TARGET_DIR)
wb = openpyxl.Workbook()
wb.save(filepath)
print(filepath)

print("Created excel file up.xlsx")


for num_tables, table in enumerate(tables, start=1):
    # get the table headers
    headers = get_table_headers(table)
    # get all the rows of the table
    rows = get_table_rows(table)
    # Create a Pandas Excel writer using XlsxWriter as the engine.
    #writer = pd.ExcelWriter('pandas_multiple.xlsx', engine='xlsxwriter')



    path = "{}up.xlsx".format(TARGET_DIR)
    book = load_workbook(path)
    writer = pd.ExcelWriter(path, engine = 'openpyxl')
    writer.book = book

    # save table as sheet
    table_name = f"table-{num_tables}"
    print(f"[+] Saving {table_name}")
    save_as_csv(table_name, headers, rows, writer)
# Out:
# /home/anm/Downloads/up.xlsx
# Created excel file up.xlsx
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-ef574b15845f> in <module>
#      12 for num_tables, table in enumerate(tables, start=1):
#      13     # get the table headers
# ---> 14     headers = get_table_headers(table)
#      15     # get all the rows of the table
#      16     rows = get_table_rows(table)
#
# <ipython-input-1-b6256a1c299a> in get_table_headers(table)
#      25     """Given a table soup, returns all the headers"""
#      26     headers = []
# ---> 27     for th in table.find("tr").find_all("th"):
#      28         headers.append(th.text.strip())
#      29     return headers
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
id_list=["ShowTableApartment","ctl00_ContentPlaceHolder1_grddevlopmentworks","dbkhasradetails",
         "ctl00_ContentPlaceHolder1_grvagents"]
tables = []

              
for i in id_list:
    temp = soup.find('table',id = i)
    temp
    tables.append(temp)
    

for i in range(0, len(tables)):

    headers = []
              
    for th in tables[i].find("tr").find_all("th"):
        headers.append(th.text.strip())

# %%
TARGET_DIR = f'/home/anm/Downloads/'

# iterate over all tables
filepath = "{}up_{}.xlsx".format(TARGET_DIR,i+1)
wb = openpyxl.Workbook()
wb.save(filepath)
print(filepath)
counter=0
print("Created excel file up_{}.xlsx".format(i+1))


for num_tables, table in enumerate(tables, start=1):
    # get the table headers
    headers = get_table_headers(table)
    # get all the rows of the table
    rows = get_table_rows(table)
    # Create a Pandas Excel writer using XlsxWriter as the engine.
    #writer = pd.ExcelWriter('pandas_multiple.xlsx', engine='xlsxwriter')
    path = "{}up_{}.xlsx".format(TARGET_DIR,i+1)
    book = load_workbook(path)
    writer = pd.ExcelWriter(path, engine = 'openpyxl')
    writer.book = book
    sheet_name=["Apartments details","Development works","Plot details","Agent name"]
    #for k in range(sheet_name):
    table_name = sheet_name[counter]
    counter=counter+1
    print(f"[+] Saving {table_name}")
    save_as_csv(table_name, headers, rows, writer)
# Out:
# /home/anm/Downloads/up_4.xlsx
# Created excel file up_4.xlsx
# [+] Saving Apartments details
# [+] Saving Development works
# [+] Saving Plot details
# [+] Saving Agent name

# %%
driver_call(url)
file=1
time.sleep(10)
Project_approved=[]         
Project_details = []


Project_details_list = [] 
#captcha=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_txtcap"]')
elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_btnSearch"]')
elementID.click()
elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl02_LnkView"]')
elementID.click()
time.sleep(10)

elementID=driver.find_element_by_xpath('//*[@id="contentSection"]/div/div/div/div/div[2]/div[27]/div[3]/a/b')
elementID.click()
time.sleep(10)
driver.switch_to.window(driver.window_handles[-1])
soup = BeautifulSoup(driver.page_source, 'lxml')
#TARGET_DIR = f'/home/anm/rera_up/sheet'
#tables = soup.find('table',id =["ShowTableApartment","ctl00_ContentPlaceHolder1_grddevlopmentworks"])
tables = soup.find('table',id ="ctl00_ContentPlaceHolder1_grddevlopmentworks")
id_list=["ShowTableApartment","ctl00_ContentPlaceHolder1_grddevlopmentworks","dbkhasradetails",
         "ctl00_ContentPlaceHolder1_grvagents"]              

#collect_table(soup, id_list)
tables = []    
for i in id_list:

    temp = soup.find('table',id = i)
    temp

    tables.append(temp)    
for i in range(0, len(tables)): 
    headers = []
for th in tables[i].find("tr").find_all("th"):
    headers.append(th.text.strip())

TARGET_DIR = f'/home/anm/Downloads/'

# iterate over all tables
filepath = "{}up_{}.xlsx".format(TARGET_DIR,i+1)
wb = openpyxl.Workbook()
wb.save(filepath)
print(filepath)
counter=0
print("Created excel file up_{}.xlsx".format(i+1))
for num_tables, table in enumerate(tables, start=1):
    # get the table headers
    headers = get_table_headers(table)
    # get all the rows of the table
    rows = get_table_rows(table)
    # Create a Pandas Excel writer using XlsxWriter as the engine.
    #writer = pd.ExcelWriter('pandas_multiple.xlsx', engine='xlsxwriter')
    path = "{}up_{}.xlsx".format(TARGET_DIR,i+1)
    book = load_workbook(path)
    writer = pd.ExcelWriter(path, engine = 'openpyxl')
    writer.book = book
    sheet_name=["Apartments details","Development works","Plot details","Agent name"]
    #for k in range(sheet_name):
    table_name = sheet_name[counter]
    counter=counter+1
    print(f"[+] Saving {table_name}")
    save_as_csv(table_name, headers, rows, writer)
# Out:
# /home/anm/Downloads/up_4.xlsx
# Created excel file up_4.xlsx
# [+] Saving Apartments details
# [+] Saving Development works
# [+] Saving Plot details
# [+] Saving Agent name

# %%
def collect_table(soup, id_list):
    
    tables = []
    
    for i in id_list:

        temp = soup.find('table',id = i)
        temp

        tables.append(temp)
# Out:
#   File "<ipython-input-19-3f5f02c4f94b>", line 3
#     global tables = []
#                   ^
# SyntaxError: invalid syntax

# %%
id_list=["ShowTableApartment","ctl00_ContentPlaceHolder1_grddevlopmentworks","dbkhasradetails",
         "ctl00_ContentPlaceHolder1_grvagents"]              

#collect_table(soup, id_list)
tables = []    
for i in id_list:

    temp = soup.find('table',id = i)
    temp

    tables.append(temp)    
for i in range(0, len(tables)): 
    headers = []
for th in tables[i].find("tr").find_all("th"):
    headers.append(th.text.strip())

TARGET_DIR = f'/home/anm/Downloads/'

# iterate over all tables
filepath = "{}up_{}.xlsx".format(TARGET_DIR,i+1)
wb = openpyxl.Workbook()
wb.save(filepath)
print(filepath)
counter=0
print("Created excel file up_{}.xlsx".format(i+1))
for num_tables, table in enumerate(tables, start=1):
    # get the table headers
    headers = get_table_headers(table)
    # get all the rows of the table
    rows = get_table_rows(table)
    # Create a Pandas Excel writer using XlsxWriter as the engine.
    #writer = pd.ExcelWriter('pandas_multiple.xlsx', engine='xlsxwriter')
    path = "{}up_{}.xlsx".format(TARGET_DIR,i+1)
    book = load_workbook(path)
    writer = pd.ExcelWriter(path, engine = 'openpyxl')
    writer.book = book
    sheet_name=["Apartments details","Development works","Plot details","Agent name"]
    #for k in range(sheet_name):
    table_name = sheet_name[counter]
    counter=counter+1
    print(f"[+] Saving {table_name}")
    save_as_csv(table_name, headers, rows, writer)
# Out:
# /home/anm/Downloads/up_4.xlsx
# Created excel file up_4.xlsx
# [+] Saving Apartments details
# [+] Saving Development works
# [+] Saving Plot details
# [+] Saving Agent name

# %%
tables = []
id_list=["ShowTableApartment","ctl00_ContentPlaceHolder1_grddevlopmentworks","dbkhasradetails",
         "ctl00_ContentPlaceHolder1_grvagents"]
for i in id_list:
    temp = soup.find('table',id = i)
    #print(temp)
    tables.append(temp)

# %%
temp = soup.find('table',id = i)

# %%
temp
# Out:
# <table border="0" cellpadding="4" cellspacing="0" class="table table-bordered table-striped" id="ctl00_ContentPlaceHolder1_grvagents" style="color:#333333;border-collapse:collapse;">
# <tbody><tr style="color:White;background-color:Orange;font-weight:bold;">
# <th scope="col">
#                                                                                                                             SNo.
#                                                                                                                         </th><th scope="col">Agent Name</th>
# </tr><tr style="color:#333333;background-color:#F7F6F3;">
# <td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl02_lblSRNO">1</span>
# </td><td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl02_Label1">INVESTORS CLINIC INFRATECH PRIVATE LIMITED</span>
# </td>
# </tr><tr style="color:#284775;background-color:White;">
# <td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl03_lblSRNO">2</span>
# </td><td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl03_Label1">SMC Real Estate Advisors Private Limited</span>
# </td>
# </tr><tr style="color:#333333;background-color:#F7F6F3;">
# <td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl04_lblSRNO">3</span>
# </td><td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl04_Label1">star estate</span>
# </td>
# </tr><tr style="color:#284775;background-color:White;">
# <td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl05_lblSRNO">4</span>
# </td><td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl05_Label1">EMPOWER REALTECH PRIVATE LIMITED</span>
# </td>
# </tr><tr style="color:#333333;background-color:#F7F6F3;">
# <td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl06_lblSRNO">5</span>
# </td><td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl06_Label1">360 REALTORS LLP</span>
# </td>
# </tr><tr style="color:#284775;background-color:White;">
# <td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl07_lblSRNO">6</span>
# </td><td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl07_Label1">JAI AMBEY CONSULTANTS</span>
# </td>
# </tr><tr style="color:#333333;background-color:#F7F6F3;">
# <td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl08_lblSRNO">7</span>
# </td><td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl08_Label1">Haveon Deal Services Pvt Ltd</span>
# </td>
# </tr><tr style="color:#284775;background-color:White;">
# <td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl09_lblSRNO">8</span>
# </td><td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl09_Label1">Kiran Singh</span>
# </td>
# </tr><tr style="color:#333333;background-color:#F7F6F3;">
# <td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl10_lblSRNO">9</span>
# </td><td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl10_Label1">GLORICE REALTY CONSULTING PRIVATE LIMITED</span>
# </td>
# </tr><tr style="color:#284775;background-color:White;">
# <td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl11_lblSRNO">10</span>
# </td><td>
# <span id="ctl00_ContentPlaceHolder1_grvagents_ctl11_Label1">Prachi Mehrotra</span>
# </td>
# </tr>
# </tbody></table>

# %%
tables.append(temp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-c30ac372e4ae> in <module>
# ----> 1 tables.append(temp)
#
# ~/.local/lib/python3.6/site-packages/bs4/element.py in append(self, tag)
#     349     def append(self, tag):
#     350         """Appends the given tag to the contents of this tag."""
# --> 351         self.insert(len(self.contents), tag)
#     352
#     353     def extend(self, tags):
#
# ~/.local/lib/python3.6/site-packages/bs4/element.py in insert(self, position, new_child)
#     277             raise ValueError("Cannot insert None into a tag.")
#     278         if new_child is self:
# --> 279             raise ValueError("Cannot insert a tag into itself.")
#     280         if (isinstance(new_child, str)
#     281             and not isinstance(new_child, NavigableString)):
#
# ValueError: Cannot insert a tag into itself.

# %%
table_name = f"sheet_name[k]-{num_tables}"

# %%
type(sheet_name[0])
# Out:
# str

# %%
headers = get_table_headers(table)

# %%
headers
# Out:
# ['SNo.', 'Agent Name']

# %%
driver_call(url)
time.sleep(5)
elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_btnSearch"]')
elementID.click()
l=["%.2d" % i for i in range(2,2833)]
for m in l:
    elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl'+str(m)+'_LnkView"]')
    elementID.click()
    time.sleep(5)
    soup = BeautifulSoup(driver.page_source, 'lxml')
    #soup.select_one("a[href*=viewprojects]")
    ntab_url = "https://www.up-rera.in/"+a[href*=viewprojects]
    driver.get(ntab_url)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-37-fac652bb9a7d> in <module>
#       5 l=["%.2d" % i for i in range(2,2833)]
#       6 for m in l:
# ----> 7     elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl'+str(m)+'_LnkView"]')
#       8     elementID.click()
#       9     time.sleep(5)
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl03_LnkView"]"}
#   (Session info: chrome=86.0.4240.111)

# %%
driver_call(url)
time.sleep(5)
elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_btnSearch"]')
elementID.click()
l=["%.2d" % i for i in range(2,2833)]
for m in l:
    elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl'+str(m)+'_LnkView"]')
    elementID.click()
    time.sleep(5)
    #soup = BeautifulSoup(driver.page_source, 'lxml')
    #soup.select_one("a[href*=viewprojects]")
    ntab_url = "https://www.up-rera.in/viewprojects"
    driver.execute_script('''window.open("","_blank");''')
    driver.switch_to.window(driver.window_handles[1])
    driver.get(ntab_url)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-40-f4a7cf66545d> in <module>
#       5 l=["%.2d" % i for i in range(2,2833)]
#       6 for m in l:
# ----> 7     elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl'+str(m)+'_LnkView"]')
#       8     elementID.click()
#       9     time.sleep(5)
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl03_LnkView"]"}
#   (Session info: chrome=86.0.4240.111)

# %%
driver_call(url)
time.sleep(10)
elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_btnSearch"]')
elementID.click()
l=["%.2d" % i for i in range(2,2833)]
for m in l:
    elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl'+str(m)+'_LnkView"]')
    elementID.click()
    time.sleep(5)
    ntab_url = "https://www.up-rera.in/viewprojects"
    driver.execute_script('''window.open("","_blank");''')
    driver.switch_to.window(driver.window_handles[1])
    driver.get(ntab_url)
    time.sleep(10)
    
    
    
    driver.switch_to.window(driver.window_handles[1])
    driver.close()
    driver.switch_to.window(driver.window_handles[0])

    
    driver.execute_script("window.history.go(-1)")
# Out:
# ['CDwindow-24139AFC034FE9D69BAA018BCCA532E2']
# ['CDwindow-24139AFC034FE9D69BAA018BCCA532E2']
# ['CDwindow-24139AFC034FE9D69BAA018BCCA532E2']
# ['CDwindow-24139AFC034FE9D69BAA018BCCA532E2']
# ['CDwindow-24139AFC034FE9D69BAA018BCCA532E2']
# ['CDwindow-24139AFC034FE9D69BAA018BCCA532E2']
# ['CDwindow-24139AFC034FE9D69BAA018BCCA532E2']
# ['CDwindow-24139AFC034FE9D69BAA018BCCA532E2']
# ['CDwindow-24139AFC034FE9D69BAA018BCCA532E2']
# ['CDwindow-24139AFC034FE9D69BAA018BCCA532E2']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-c61a1a5898d9> in <module>
#      13     driver.get(ntab_url)
#      14     time.sleep(10)
# ---> 15     driver.switch_to.window(driver.window_handles[1])
#      16     driver.close()
#      17     driver.switch_to.window(driver.window_handles[0])
#
# IndexError: list index out of range

# %%
driver_call(url)
k=99
Project_details=[]
Project_details_list=[]
time.sleep(5)
elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_btnSearch"]')
elementID.click()
#l=["%.2d" % i for i in range(100,2833)]
#for m in l:
for m in range(100,2833):
    elementID=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_GridView1_ctl'+str(m)+'_LnkView"]')
    elementID.click()
    time.sleep(5)
    ntab_url = "https://www.up-rera.in/viewprojects"
    driver.execute_script('''window.open("","_blank");''')
    driver.switch_to.window(driver.window_handles[1])
    driver.get(ntab_url)
    time.sleep(10)
    driver.switch_to.window(driver.window_handles[-1])
    soup = BeautifulSoup(driver.page_source, 'lxml')
    Project_name=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblProjectName"]').text
    Project_id=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblProjectNameWithID"]').text
    Registration_date=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblregisdate"]').text
    Promoter_name=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblPromoterNameHeading"]').text
    Promoter_id=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblPromoterNameWithID"]').text
    Project_type=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblProjectType"]').text
    Project_category=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblProjectCategory"]').text
    total_area=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblTotalArea"]').get_attribute("value")
    Registration_fee=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_PanelBasicDetails"]/div/div/fieldset/table/tbody/tr[5]/td[4]').text
    Project_duratin_in_month=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblProjectDuration"]').text
    Orginal_start_date=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblOriginalStartDate"]').get_attribute("value")
    Proposed_start_date=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblStartDate"]').get_attribute("value")
    Proposed_completion_date=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblEndDate"]').get_attribute("value")
    Project_cost=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblProjectCost"]').get_attribute("value")
    Sanctioning_Competent_Authority=soup.find('select', id = 'ctl00_ContentPlaceHolder1_ddlAuthority').find('option', selected = True).text
    Tehsil=soup.find('select', id = 'ctl00_ContentPlaceHolder1_ddlTehsil').find('option', selected = True).text
    District=soup.find('select', id = 'ctl00_ContentPlaceHolder1_ddlDistrict').find('option', selected = True).text
    State=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblState"]').text
    Latitute=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblLat1"]').get_attribute("value")
    Longtitute=driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_lblLong1"]').get_attribute("value")
    id_list=["ShowTableApartment","ctl00_ContentPlaceHolder1_grddevlopmentworks","dbkhasradetails",
             "ctl00_ContentPlaceHolder1_grvagents"]              
    driver.switch_to.window(driver.window_handles[-1])
    soup = BeautifulSoup(driver.page_source, 'lxml')
    #TARGET_DIR = f'/home/anm/rera_up/sheet'
    #tables = soup.find('table',id =["ShowTableApartment","ctl00_ContentPlaceHolder1_grddevlopmentworks"])
    tables = soup.find('table',id ="ctl00_ContentPlaceHolder1_grddevlopmentworks")
    #collect_table(soup, id_list)
    tables = []
    table=[]
    title=[]
    for i in id_list:



        temp = soup.find('table',id = i)
        temp

        if temp != None:
            if temp.find("tr") is None:
                print("NONE")
            else:
                if i == "ShowTableApartment":
                    title_temp = "Apartments details"
                elif  i == "ctl00_ContentPlaceHolder1_grddevlopmentworks":
                    title_temp = "Development works"
                elif i == "dbkhasradetails":
                    title_temp = "Plot details"
                elif i == "ctl00_ContentPlaceHolder1_grvagents":
                    title_temp = "Agent name"

                table.append(temp)
                title.append(title_temp)

        else:
            print("Table not found")


    TARGET_DIR = f'/home/anm/rera_up/sheet/'

    # iterate over all tables
    filepath = "{}project_{}.xlsx".format(TARGET_DIR,k+1)
    wb = openpyxl.Workbook()
    wb.save(filepath)
    print(filepath)
    counter=0
    print("Created excel file project_{}.xlsx".format(k+1))

    num_title = 0

    for num_tables, table_index in enumerate(table, start=1):
        # get the table headers
        headers = get_table_headers(table_index)
        # get all the rows of the table
        rows = get_table_rows(table_index)
        # Create a Pandas Excel writer using XlsxWriter as the engine.
        #writer = pd.ExcelWriter('pandas_multiple.xlsx', engine='xlsxwriter')
        path = "{}project_{}.xlsx".format(TARGET_DIR,k+1)
        book = load_workbook(path)
        writer = pd.ExcelWriter(path, engine = 'openpyxl')
        writer.book = book
        sheet_name = title[num_title]
        num_title = num_title + 1
        #for k in range(sheet_name):
        table_name = sheet_name
        counter=counter+1
        print(f"[+] Saving {table_name}")
        save_as_csv(table_name, headers, rows, writer)

    Project_details = [Project_name,Project_id,Registration_date,Promoter_name,Promoter_id,Project_type,
                     Project_category,total_area,Registration_fee,Project_duratin_in_month,Orginal_start_date,
                       Proposed_start_date,Proposed_completion_date,Project_cost,Sanctioning_Competent_Authority,
                       Tehsil,District,State,Latitute,Longtitute]
    Project_details_list.append(Project_details)
    time.sleep(5)
    #driver.close()
    driver.switch_to.window(driver.window_handles[1])
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
    driver.execute_script("window.history.go(-1)")
    k=k+1
#driver.switch_to.window(driver.window_handles[-1])
#driver.execute_script("window.history.go(-1)")
Project_details_list_df = pd.DataFrame(Project_details_list,columns =['Project_name','Project_id','Registration_date','Promoter_name','Promoter_id','Project_type',
                 'Project_category','total_area','Registration_fee','Project_duratin_in_month','Orginal_start_date',
                   'Proposed_start_date','Proposed_completion_date','Project_cost','Sanctioning_Competent_Authority',
                   'Tehsil','District','State','Latitute','Longtitute'])


Project_details_list_df.to_csv("/home/anm/rera_up/project_up_mis2.csv", index = False)
print("Task Completed")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-65-962600d15fac> in <module>
# ----> 1 driver_call(url)
#       2 k=99
#       3 Project_details=[]
#       4 Project_details_list=[]
#       5 time.sleep(5)
#
# <ipython-input-1-b6256a1c299a> in driver_call(url)
#      14         driver = webdriver.Chrome(executable_path="/home/anm/Downloads/chromedriver_linux64 (2)/chromedriver")
#      15         #driver= webdriver.Chrome(executable_path="/home/anm/Downloads/chromedriver_linux64/chromedriver")
# ---> 16         driver.get(url)
#      17         time.sleep(8)
#      18 def get_all_tables(soup):
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.local/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: cannot determine loading status
# from disconnected: received Inspector.detached event
#   (Session info: chrome=86.0.4240.111)

# %%
Project_details_list_df = pd.DataFrame(Project_details_list,columns =['Project_name','Project_id','Registration_date','Promoter_name','Promoter_id','Project_type',
                 'Project_category','total_area','Registration_fee','Project_duratin_in_month','Orginal_start_date',
                   'Proposed_start_date','Proposed_completion_date','Project_cost','Sanctioning_Competent_Authority',
                   'Tehsil','District','State','Latitute','Longtitute'])


Project_details_list_df.to_csv("/home/anm/rera_up/project_up_mis2.csv", index = False)
print("Task Completed")
# Out:
# Task Completed

# %%
soup.findAll('div', class_= 'panel-heading')
# Out:
# [<div class="panel-heading">
#  <h3>View Project Detail : All Information</h3>
#  </div>, <div class="panel-heading">
#  <h4 style="background-color:#518b93;color:white; height: 40px; clear: both; color: #ddd; background-color: #518b93; padding: 10px 20px; font-family: 'Oswald',sans-serif; transition: all 0.5s;"><strong>Other Details</strong></h4>
#  </div>, <div class="panel-heading">
#  <h4 style="background-color:#518b93;color:white; height: 40px; clear: both; color: #ddd; background-color: #518b93; padding: 10px 20px; font-family: 'Oswald',sans-serif; transition: all 0.5s;"><strong>Development Works (Brief Description)</strong></h4>
#  </div>, <div class="panel-heading">
#  <h4 style="background-color: #518b93; color: white; height: 40px; clear: both; color: #ddd; background-color: #518b93; padding: 10px 20px; font-family: 'Oswald',sans-serif; transition: all 0.5s;"><strong>Project Bank Details</strong></h4>
#  </div>, <div class="panel-heading">
#  <h4 style="background-color: #518b93; color: white; height: 40px; clear: both; color: #ddd; background-color: #518b93; padding: 10px 20px; font-family: 'Oswald',sans-serif; transition: all 0.5s;"><strong>Land Details</strong></h4>
#  </div>, <div class="panel-heading">
#  <h4 style="background-color: #518b93; color: white; height: 40px; clear: both; color: #ddd; background-color: #518b93; padding: 10px 20px; font-family: 'Oswald',sans-serif; transition: all 0.5s;"><strong>Land Detail</strong></h4>
#  </div>]

# %%
tables = []
table=[]
title=[]
for i in id_list:



    temp = soup.find('table',id = i)
    temp

    if temp != None:
        if temp.find("tr") is None:
            print("NONE")
        else:
            if i == "ShowTableApartment":
                title_temp = "Apartments details"
            elif  i == "ctl00_ContentPlaceHolder1_grddevlopmentworks":
                title_temp = "Development works"
            elif i == "dbkhasradetails":
                title_temp = "Plot details"
            elif i == "ctl00_ContentPlaceHolder1_grvagents":
                title_temp = "Agent name"

            table.append(temp)
            title.append(title_temp)

    else:
        print("Table not found")


TARGET_DIR = f'/home/anm/rera_up/sheet/'

# iterate over all tables
filepath = "{}project_{}.xlsx".format(TARGET_DIR,k+1)
wb = openpyxl.Workbook()
wb.save(filepath)
print(filepath)
counter=0
print("Created excel file project_{}.xlsx".format(k+1))

num_title = 0

for num_tables, table_index in enumerate(table, start=1):
    # get the table headers
    headers = get_table_headers(table_index)
    # get all the rows of the table
    rows = get_table_rows(table_index)
    # Create a Pandas Excel writer using XlsxWriter as the engine.
    #writer = pd.ExcelWriter('pandas_multiple.xlsx', engine='xlsxwriter')
    path = "{}project_{}.xlsx".format(TARGET_DIR,k+1)
    book = load_workbook(path)
    writer = pd.ExcelWriter(path, engine = 'openpyxl')
    writer.book = book
    sheet_name = title[num_title]
    num_title = num_title + 1
    #for k in range(sheet_name):
    table_name = sheet_name
    counter=counter+1
    print(f"[+] Saving {table_name}")
    save_as_csv(table_name, headers, rows, writer)
# Out:
# NONE
# Table not found
# Table not found
# /home/anm/rera_up/sheet/project_1.xlsx
# Created excel file project_1.xlsx
# [+] Saving Plot details

# %%
temp = soup.find('table',id = i)

# %%
soup.find('table',id = "ctl00_ContentPlaceHolder1_grddevlopmentworkinsert")
# Out:
# <table border="1" cellspacing="0" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert" rules="all" style="width:100%;border-collapse:collapse;">
# <tbody><tr>
# <th scope="col" style="height:40px;width:50%;">Development Work Name</th><th scope="col">Enter Brief Description</th>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl02_workname">Demarcation of Plots</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl02_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl02$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl02_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl03_workname">Boundary Wall</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl03_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl03$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl03_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl04_workname">Road Work</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl04_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl04$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl04_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl05_workname">Footpaths</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl05_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl05$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl05_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl06_workname">Water Supply Including Drinking Water Facilities</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl06_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl06$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl06_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl07_workname">Sewer System</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl07_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl07$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl07_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl08_workname">Drain</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl08_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl08$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl08_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl09_workname">Parks</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl09_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl09$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl09_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl10_workname">Tree Planting</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl10_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl10$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl10_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl11_workname">Design For Electric Supply Including Street Lighting</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl11_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl11$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl11_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl12_workname">Community Buildings</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl12_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl12$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl12_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl13_workname">Treatment and Disposal System of Sewage and Sullage water</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl13_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl13$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl13_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl14_workname">Solid Waste Management And Disposal System</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl14_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl14$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl14_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl15_workname">Water Conservation System</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl15_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl15$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl15_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl16_workname">Energy Management System Including Use of Renewable Energy</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl16_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl16$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl16_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl17_workname">Fire Protection And Fire Safety System</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl17_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl17$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl17_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl18_workname">Social Infrastructure And Other Public Amenities Including Public Health Services</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl18_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl18$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl18_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl19_workname">Emergency Evacuation Services</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl19_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl19$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl19_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr><tr>
# <td>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl20_workname">Other Miscellaneous   Work</span><span style="color: red">*</span>
# </td><td>
# <textarea class="form-control" cols="70" disabled="disabled" id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl20_txtworkdetails" name="ctl00$ContentPlaceHolder1$grddevlopmentworkinsert$ctl20$txtworkdetails" rows="3"></textarea>
# <span id="ctl00_ContentPlaceHolder1_grddevlopmentworkinsert_ctl20_rvtxtwork" style="color:Red;visibility:hidden;">*</span>
# </td>
# </tr>
# </tbody></table>

# %%
tables = []
table=[]
for i in id_list:

    temp = soup.find('table',id = i)
    temp

    if temp != None:
        if temp.find("tr") is not None:
            table.append(temp) 
    else:
        print("Table not found")
    

for val in table:
    if val != None:
        tables.append(val)

TARGET_DIR = f'/home/anm/rera_up/sheet/'

# iterate over all tables
filepath = "{}project_{}.xlsx".format(TARGET_DIR,k+1)
wb = openpyxl.Workbook()
wb.save(filepath)
print(filepath)
counter=0
print("Created excel file project_{}.xlsx".format(k+1))
for num_tables, table in enumerate(tables, start=1):
    # get the table headers
    headers = get_table_headers(table)
    # get all the rows of the table
    rows = get_table_rows(table)
    # Create a Pandas Excel writer using XlsxWriter as the engine.
    #writer = pd.ExcelWriter('pandas_multiple.xlsx', engine='xlsxwriter')
    path = "{}project_{}.xlsx".format(TARGET_DIR,k+1)
    book = load_workbook(path)
    writer = pd.ExcelWriter(path, engine = 'openpyxl')
    writer.book = book
    sheet_name=["Apartments details","Development works","Plot details","Agent name"]
    #for k in range(sheet_name):
    table_name = sheet_name[counter]
    counter=counter+1
    print(f"[+] Saving {table_name}")
    save_as_csv(table_name, headers, rows, writer)
# Out:
# Table not found
# Table not found
# /home/anm/rera_up/sheet/project_8.xlsx
# Created excel file project_8.xlsx
# [+] Saving Apartments details

# %%
for il in range(len(tables)):
    print(il)

# %%
il
# Out:
# 0

# %%
for il in range(len(tables)):

                table_topic_list = []
                print(id_list[il])


                table_header = soup.find("div", id = tables[il])
                #table.select("h2")

                if(len(table_header) > 0):
                    for j in range(len(table_header)):
                        table_topic=table_header[j].text
                        print(table_topic)
                        table_topic_list.append(table_topic)
                else: 
                    print("No header")
                    table_topic = 'NA'
                    table_topic_list.append(table_topic)

# %%
print(table_topic)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a541e7f75f85> in <module>
# ----> 1 print(table_topic)
#
# NameError: name 'table_topic' is not defined

# %%
if tables[0].find("tr") is None:
    print("Not availabe")
else:
    for th in tables[0].find("tr").find_all("th"):
        headers.append(th.text.strip())
# Out:
# Not availabe

# %%
tables
# Out:
# [<table border="1" class="table table-responsive" id="ShowTableApartment" style=" display:none;width: 100%!important">
#  </table>, <table border="1" class="table" id="dbkhasradetails"><tbody><tr>
#  <th>Type</th>
#  <th>Khasra/Plot No</th>
#  <th>Area(In Sq. Mt.)</th>
#  </tr></tbody></table>]

# %%
print(temp)
# Out:
# None

# %%
soup.find_all("a")
# Out:
# [<a class="taglib-language-list-text" href="#" style="font-size: 14px;">
#  </a>,
#  <a href="https://facebook.com/upreraofficial" target="_blank" title="Facebook"><i class="fa fa-facebook"></i></a>,
#  <a href="https://twitter.com/UPRERAofficial" target="_blank" title="Twitter"><i class="fa fa-twitter"></i></a>,
#  <a href="https://www.youtube.com/channel/UCAeF0bOHPpzN-K9QvfA9rSQ" target="_blank" title="Youtube"><i class="fa fa-youtube-play" style="color:red"></i></a>,
#  <a class="taglib-language-list-text" href="#main" style="font-size: 14px;">|<span class="fa fa-home"></span> Skip to main content  </a>,
#  <a class="letterSize round-icons navMal a-plus" href="#" title="Increase font size">+A</a>,
#  <a class="letterSize round-icons navMal a-normal font_size_add" href="#" style="padding: 2px 6px 2px 6px;" title="Restore default font size">A</a>,
#  <a class="letterSize round-icons navMal a-minus font_size_minus" href="#" style="" title="Decrease font size">-A</a>,
#  <a class="navbar-brand logo_h" href="index" style="padding-top: 10px;">
#  <img alt="UPRERA" class="img-responsive" src="img/rera_logo.png"/></a>,
#  <a href="#ctl00_menuBar_SkipLink"><img alt="Skip Navigation Links" height="0" src="/WebResource.axd?d=rKN1opQVoh180LaGjXZZkBS12eNuTEkJSK3LZN619Di8dslzlPBXBuZ-Mf7L67b5Xil6pU8j0byDihpsHSLd4g2&amp;t=637327039249080682" style="border-width:0px;" width="0"/></a>,
#  <a class="nav-link" href="index.aspx" tabindex="-1"><i aria-hidden="true" class="fa fa-home"></i> Home</a>,
#  <a class="nav-link dropdown-toggle" href="#" tabindex="-1">ABOUT RERA</a>,
#  <a class="level2 dropdown-item" href="about" tabindex="-1">INTRODUCTION</a>,
#  <a class="level2 dropdown-item" href="leadership" tabindex="-1">OUR LEADERSHIP</a>,
#  <a class="level2 dropdown-item nav-link dropdown-toggle dropdownRight" href="#" tabindex="-1">MEDIA SECTION</a>,
#  <a class="level3 dropdown-item" href="GalleryDashboard" tabindex="-1">PHOTO GALLERY</a>,
#  <a class="level3 dropdown-item" href="VideoDashboard" tabindex="-1">VIDEO GALLERY</a>,
#  <a class="level3 dropdown-item" href="PressRelease" tabindex="-1">PRESS RELEASES</a>,
#  <a class="level3 dropdown-item" href="reranews" tabindex="-1">IN NEWS</a>,
#  <a class="level3 dropdown-item" href="frm_interviews.aspx" tabindex="-1">INTERVIEWS</a>,
#  <a class="level2 dropdown-item" href="pdf/RERA%20REPORT6919.pdf" tabindex="-1">UP-RERA Annual Report 2018-19</a>,
#  <a class="level2 dropdown-item" href="pdf/Best_Practices_by_UP-RERA.pdf" tabindex="-1">E-Book on Best Practices</a>,
#  <a class="nav-link dropdown-toggle" href="#" tabindex="-1">LEGAL</a>,
#  <a class="level2 dropdown-item" href="pdf/reraact.pdf" tabindex="-1">ACTS</a>,
#  <a class="level2 dropdown-item" href="pdf/rera.pdf" tabindex="-1">RULES</a>,
#  <a class="level2 dropdown-item" href="pdf/UPRERA_Regulation_2019.pdf" tabindex="-1">REGULATIONS</a>,
#  <a class="level2 dropdown-item" href="pdf/rerenotification.pdf" tabindex="-1">NOTIFICATIONS</a>,
#  <a class="level2 dropdown-item" href="pdf/UPRERA_ATS_2018.pdf" tabindex="-1">AGREEMENT FOR SALE/LEASE</a>,
#  <a class="nav-link dropdown-toggle" href="#" tabindex="-1">REGISTRATIONS</a>,
#  <a class="level2 dropdown-item" href="project" tabindex="-1">PROMOTER</a>,
#  <a class="level2 dropdown-item" href="login" tabindex="-1">PROJECT</a>,
#  <a class="level2 dropdown-item" href="agentregister" tabindex="-1">AGENT</a>,
#  <a class="nav-link dropdown-toggle" href="#" tabindex="-1">CONCILIATION FORUM</a>,
#  <a class="level2 dropdown-item" href="conciliations" tabindex="-1">CONCILIATION LOGIN</a>,
#  <a class="level2 dropdown-item" href="ConciliationDetails" tabindex="-1">CONCILIATION STATUS</a>,
#  <a class="nav-link dropdown-toggle" href="#" tabindex="-1">COMPLAINTS </a>,
#  <a class="level2 dropdown-item" href="SignUp" tabindex="-1">REGISTER COMPLAINT</a>,
#  <a class="level2 dropdown-item" href="SignUp" tabindex="-1">COMPLAINT FOR COMPENSATION</a>,
#  <a class="level2 dropdown-item" href="viewcomplaint" tabindex="-1">COMPLAINT STATUS</a>,
#  <a class="level2 dropdown-item" href="getcomplaint" tabindex="-1">GET COMPLAINT NUMBER</a>,
#  <a class="level2 dropdown-item" href="NonRegistration" tabindex="-1">INFORMATION ABOUT UN-REGISTERED PROJECT</a>,
#  <a class="level2 dropdown-item" href="frm_ViewDetails_unregistered_project.aspx" tabindex="-1">VIEW STATUS OF INFORMATION ABOUT UN-REGISTER PROJECT</a>,
#  <a class="nav-link dropdown-toggle" href="#" tabindex="-1">REQUEST</a>,
#  <a class="level2 dropdown-item" href="Requestdoc" tabindex="-1">REQUEST FOR DOCUMENTS</a>,
#  <a class="level2 dropdown-item" href="frm_OrderExecution.aspx" tabindex="-1">REQUEST FOR ORDER EXECUTION</a>,
#  <a class="level2 dropdown-item" href="frm_Rc_Report.aspx" tabindex="-1">VIEW RC STATUS</a>,
#  <a class="nav-link dropdown-toggle" href="#" tabindex="-1">LOGIN</a>,
#  <a class="level2 dropdown-item" href="login" tabindex="-1">USER LOGIN</a>,
#  <a class="level2 dropdown-item" href="admin" tabindex="-1">ADMIN LOGIN</a>,
#  <a class="level2 dropdown-item" href="InspectionOfficerLogin.aspx" tabindex="-1">INSPECTION LOGIN</a>,
#  <a class="level2 dropdown-item" href="SignUp" tabindex="-1">E-Court Login/Sign Up</a>,
#  <a class="nav-link dropdown-toggle" href="#" tabindex="-1">DOWNLOADS</a>,
#  <a class="level2 dropdown-item" href="finalcertificates/finalcertificates/CACertificate.xlsx" tabindex="-1">CA Certificate</a>,
#  <a class="level2 dropdown-item" href="finalcertificates/finalcertificates/ArchitechtCertificate.xlsx" tabindex="-1">Architect Certificate</a>,
#  <a class="level2 dropdown-item" href="finalcertificates/finalcertificates/EngineersCertificate.xlsx" tabindex="-1">Engineers Certificate</a>,
#  <a class="nav-link" href="applicationform" tabindex="-1">CAREER</a>,
#  <a class="nav-link" href="ContactUs" tabindex="-1">CONTACT US</a>,
#  <a id="ctl00_menuBar_SkipLink"></a>,
#  <a class="navbar-brand logo_h" href="index.aspx" style="padding-right: 0">
#  <img alt="Hon'ble CM YOGI ADITYANATH" class="img-responsive" src="images/cm.png" style="height: 95px; max-width: 100px;" title="Hon'ble CM YOGI ADITYANATH"/></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/431423014144.pdf" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/901932121941.pdf" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/441931111329.jpg" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/123342049019.pdf" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/304333403344.pdf" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/414444411442.pdf" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/101390403400.pdf" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/911134100149.pdf" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/149013039111.jpg" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/012304911429.pdf" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/440434113124.jpg" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/302130492942.pdf" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/044301422444.pdf" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/499303499020.jpg" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/344110114193.pdf" target="_blank"><i class="fa fa-download"></i></a>,
#  <a href="http://rera.mp.gov.in/upload/project_upload/030339933413.jpg" target="_blank"><i class="fa fa-download"></i></a>,
#  <a id="A8" onclick="showModalPopUp('')" style="padding: 10px;background-color: #f7d0d0;float:left;cursor: pointer;width: 100%;text-align: center;border-radius: 40px;"><b style="color:green">Click Here To View Project Summary</b></a>,
#  <a href="viewprojects" style="padding: 10px;background-color: #f7d0d0;float: right;cursor:pointer;width: 100%;text-align: center;border-radius: 40px;" target="_blank"><b>Click Here To View Complete Project Details</b></a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl02$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl02_Lnkdownload" style="color: black"></a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl03$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl03_Lnkdownload" style="color: black"></a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl04$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl04_Lnkdownload" style="color: black"></a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl05$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl05_Lnkdownload" style="color: black"></a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl06$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl06_Lnkdownload" style="color: black"></a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl07$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl07_Lnkdownload" style="color: black"></a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl08$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl08_Lnkdownload" style="color: black"></a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl09$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl09_Lnkdownload" style="color: black"></a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl10$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl10_Lnkdownload" style="color: black"></a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl11$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl11_Lnkdownload" style="color: black"></a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl12$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl12_Lnkdownload" style="color: black"></a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl13$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl13_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl14$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl14_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl15$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl15_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl16$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl16_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl17$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl17_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl18$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl18_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl19$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl19_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl20$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl20_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl21$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl21_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl22$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl22_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl23$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl23_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl24$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl24_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl25$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl25_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl26$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl26_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl27$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl27_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl28$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl28_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl29$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl29_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl30$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl30_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl31$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl31_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl32$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl32_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl33$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl33_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl34$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl34_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl35$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl35_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl36$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl36_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl37$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl37_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl38$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl38_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl39$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl39_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl40$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl40_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl41$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl41_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl42$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl42_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl43$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl43_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl44$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl44_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl45$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl45_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl46$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl46_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl47$Lnkdownload','')" id="ctl00_ContentPlaceHolder1_grvdocumentdetails_ctl47_Lnkdownload" style="color: black">Download</a>,
#  <a href="javascript:" id="return-to-top"><i class="fas fa-chevron-up"></i></a>,
#  <a class="navbar-brand logo_h" href="index">
#  <img alt="" src="img/rera_logo.png"/></a>,
#  <a href="index">home</a>,
#  <a href="AboutUs" target="_blank">about </a>,
#  <a href="career" target="_blank">career </a>,
#  <a href="Media" target="_blank">media</a>,
#  <a href="downloads" target="_blank">downloads</a>,
#  <a href="ContactUs" target="_blank">contact us</a>,
#  <a href="https://facebook.com/upreraofficial" target="_blank" title="Facebook"><i class="ti-angle-right"></i>Facebook</a>,
#  <a href="#" title="Google"><i class="ti-angle-right"></i>Google</a>,
#  <a href="https://twitter.com/UPRERAofficial" target="_blank" title="Twitter"><i class="ti-angle-right"></i>Twitter</a>,
#  <a href="#" title="Linked In"><i class="ti-angle-right"></i>LinkedIn</a>,
#  <a href="https://www.youtube.com/channel/UCAeF0bOHPpzN-K9QvfA9rSQ" target="_blank" title="Youtube"><i class="ti-angle-right"></i>Youtube</a>,
#  <a href="pdf/UPRERA_ATS_2018.pdf" target="_blank"><i class="ti-angle-right"></i>Agreement for Sale/Lease</a>,
#  <a href="pdf/Order for CA,Architect,Engineer Certificate.pdf" target="_blank"><i class="ti-angle-right"></i>Order for CA, Architect, Engineer Certificate</a>,
#  <a href="pdf/Portal_Editing_order.pdf" target="_blank"><i class="ti-angle-right"></i>Order For Project Registration &amp; Editing</a>,
#  <a href="pdf/SOP.pdf" target="_blank"><i class="ti-angle-right"></i>SOP for Complaint Redressal</a>,
#  <a href="notices" target="_blank"><i class="ti-angle-right"></i>Click For More Notices...</a>]

# %%
links = []
for link in soup.findAll('a'):
        links.append(link.get('href'))
print(links)
# Out:
# ['#', 'https://facebook.com/upreraofficial', 'https://twitter.com/UPRERAofficial', 'https://www.youtube.com/channel/UCAeF0bOHPpzN-K9QvfA9rSQ', '#main', '#', '#', '#', 'index', '#ctl00_menuBar_SkipLink', 'index.aspx', '#', 'about', 'leadership', '#', 'GalleryDashboard', 'VideoDashboard', 'PressRelease', 'reranews', 'frm_interviews.aspx', 'pdf/RERA%20REPORT6919.pdf', 'pdf/Best_Practices_by_UP-RERA.pdf', '#', 'pdf/reraact.pdf', 'pdf/rera.pdf', 'pdf/UPRERA_Regulation_2019.pdf', 'pdf/rerenotification.pdf', 'pdf/UPRERA_ATS_2018.pdf', '#', 'project', 'login', 'agentregister', '#', 'conciliations', 'ConciliationDetails', '#', 'SignUp', 'SignUp', 'viewcomplaint', 'getcomplaint', 'NonRegistration', 'frm_ViewDetails_unregistered_project.aspx', '#', 'Requestdoc', 'frm_OrderExecution.aspx', 'frm_Rc_Report.aspx', '#', 'login', 'admin', 'InspectionOfficerLogin.aspx', 'SignUp', '#', 'finalcertificates/finalcertificates/CACertificate.xlsx', 'finalcertificates/finalcertificates/ArchitechtCertificate.xlsx', 'finalcertificates/finalcertificates/EngineersCertificate.xlsx', 'applicationform', 'ContactUs', None, 'index.aspx', 'http://rera.mp.gov.in/upload/project_upload/431423014144.pdf', 'http://rera.mp.gov.in/upload/project_upload/', 'http://rera.mp.gov.in/upload/project_upload/901932121941.pdf', 'http://rera.mp.gov.in/upload/project_upload/441931111329.jpg', 'http://rera.mp.gov.in/upload/project_upload/123342049019.pdf', 'http://rera.mp.gov.in/upload/project_upload/304333403344.pdf', 'http://rera.mp.gov.in/upload/project_upload/414444411442.pdf', 'http://rera.mp.gov.in/upload/project_upload/101390403400.pdf', 'http://rera.mp.gov.in/upload/project_upload/911134100149.pdf', 'http://rera.mp.gov.in/upload/project_upload/', 'http://rera.mp.gov.in/upload/project_upload/149013039111.jpg', 'http://rera.mp.gov.in/upload/project_upload/012304911429.pdf', 'http://rera.mp.gov.in/upload/project_upload/', 'http://rera.mp.gov.in/upload/project_upload/440434113124.jpg', 'http://rera.mp.gov.in/upload/project_upload/302130492942.pdf', 'http://rera.mp.gov.in/upload/project_upload/044301422444.pdf', 'http://rera.mp.gov.in/upload/project_upload/499303499020.jpg', 'http://rera.mp.gov.in/upload/project_upload/344110114193.pdf', 'http://rera.mp.gov.in/upload/project_upload/030339933413.jpg', None, 'viewprojects', "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl02$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl03$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl04$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl05$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl06$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl07$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl08$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl09$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl10$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl11$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl12$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl13$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl14$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl15$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl16$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl17$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdocumentdetails$ctl18$Lnkdownload','')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$grvdo ...

# %%
soup.select_one("a[href*=viewprojects]").click
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-3ce42f4f289d> in <module>
# ----> 1 soup.select_one("a[href*=viewprojects]").click()
#
# TypeError: 'NoneType' object is not callable

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')

# %%
    elementID=driver.find_element_by_xpath('//*[@id="contentSection"]/div/div/div/div/div[2]/div[27]/div[3]/a/b')
    elementID.click()
    time.sleep(10)
    driver.switch_to.window(driver.window_handles[1])
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
    print(driver.window_handles)
    
    driver.execute_script("window.history.go(-1)")
